# %% [markdown]
# ### Dataframes
# - table of data ( series column)
# - row axis = 0
# - row axis = 1
# - shape, index, columns , axes , dtype

# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame(
    {"id": [1,2],
     "store_nbr":[1,2],
     "family" : ["POULTRY","PRODUCE"]
    })
df
# Out:
#    id  store_nbr   family
# 0   1          1  POULTRY
# 1   2          2  PRODUCE

# %%
print(f"shape : {df.shape}")
print(f"size : {df.size}")
print(f"index : {df.index}")
print(f"columns : {df.columns}")
print(f"dtypes : {df.dtypes}")
# Out:
# shape : (2, 3)
# size : 6
# index : RangeIndex(start=0, stop=2, step=1)
# columns : Index(['id', 'store_nbr', 'family'], dtype='object')
# dtypes : id            int64
# store_nbr     int64
# family       object
# dtype: object

# %%
retail_df = pd.read_csv("./retail/stores.csv")
retail_df
# Out:
#     store_nbr           city                           state type  cluster
# 0           1          Quito                       Pichincha    D       13
# 1           2          Quito                       Pichincha    D       13
# 2           3          Quito                       Pichincha    D        8
# 3           4          Quito                       Pichincha    D        9
# 4           5  Santo Domingo  Santo Domingo de los Tsachilas    D        4
# 5           6          Quito                       Pichincha    D       13
# 6           7          Quito                       Pichincha    D        8
# 7           8          Quito                       Pichincha    D        8
# 8           9          Quito                       Pichincha    B        6
# 9          10          Quito                       Pichincha    C       15
# 10         11        Cayambe                       Pichincha    B        6
# ...

# %%
oil = pd.read_csv("./retail/oil.csv")
oil
# Out:
#             date  dcoilwtico
# 0     2013-01-01         NaN
# 1     2013-01-02       93.14
# 2     2013-01-03       92.97
# 3     2013-01-04       93.12
# 4     2013-01-07       93.20
# ...          ...         ...
# 1213  2017-08-25       47.65
# 1214  2017-08-28       46.40
# 1215  2017-08-29       46.46
# 1216  2017-08-30       45.96
# 1217  2017-08-31       47.26
#
# [1218 rows x 2 columns]

# %%
oil.shape
# Out:
# (1218, 2)

# %%
oil.index
# Out:
# RangeIndex(start=0, stop=1218, step=1)

# %%
oil.columns
# Out:
# Index(['date', 'dcoilwtico'], dtype='object')

# %%
oil.columns = ['price_date', 'oil_prices']

# %%
oil
# Out:
#       price_date  oil_prices
# 0     2013-01-01         NaN
# 1     2013-01-02       93.14
# 2     2013-01-03       92.97
# 3     2013-01-04       93.12
# 4     2013-01-07       93.20
# ...          ...         ...
# 1213  2017-08-25       47.65
# 1214  2017-08-28       46.40
# 1215  2017-08-29       46.46
# 1216  2017-08-30       45.96
# 1217  2017-08-31       47.26
#
# [1218 rows x 2 columns]

# %%
oil.axes
# Out:
# [RangeIndex(start=0, stop=1218, step=1),
#  Index(['price_date', 'oil_prices'], dtype='object')]

# %%
oil.dtypes
# Out:
# price_date     object
# oil_prices    float64
# dtype: object

# %% [markdown]
# # Exercise 1

# %%
transactions = pd.read_csv("./retail/transactions.csv")

transactions
# Out:
#              date  store_nbr  transactions
# 0      2013-01-01         25           770
# 1      2013-01-02          1          2111
# 2      2013-01-02          2          2358
# 3      2013-01-02          3          3487
# 4      2013-01-02          4          1922
# ...           ...        ...           ...
# 83483  2017-08-15         50          2804
# 83484  2017-08-15         51          1573
# 83485  2017-08-15         52          2255
# 83486  2017-08-15         53           932
# 83487  2017-08-15         54           802
#
# [83488 rows x 3 columns]

# %%
# number of rows and columns 
transactions.shape
# Out:
# (83488, 3)

# %%
# name of the columns 
transactions.columns
# Out:
# Index(['date', 'store_nbr', 'transactions'], dtype='object')

# %%
transactions.dtypes
# Out:
# date            object
# store_nbr        int64
# transactions     int64
# dtype: object

# %% [markdown]
# # explore a dataframe

# %%
df.head()
# Out:
#    id  store_nbr   family
# 0   1          1  POULTRY
# 1   2          2  PRODUCE

# %%
df.tail()
# Out:
#    id  store_nbr   family
# 0   1          1  POULTRY
# 1   2          2  PRODUCE

# %%
df.sample()
# Out:
#    id  store_nbr   family
# 1   2          2  PRODUCE

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   id         2 non-null      int64
#  1   store_nbr  2 non-null      int64
#  2   family     2 non-null      object
# dtypes: int64(2), object(1)
# memory usage: 176.0+ bytes

# %%
df.describe()
# Out:
#              id  store_nbr
# count  2.000000   2.000000
# mean   1.500000   1.500000
# std    0.707107   0.707107
# min    1.000000   1.000000
# 25%    1.250000   1.250000
# 50%    1.500000   1.500000
# 75%    1.750000   1.750000
# max    2.000000   2.000000

# %%
df.describe(include = 'all')
# Out:
#               id  store_nbr   family
# count   2.000000   2.000000        2
# unique       NaN        NaN        2
# top          NaN        NaN  POULTRY
# freq         NaN        NaN        1
# mean    1.500000   1.500000      NaN
# std     0.707107   0.707107      NaN
# min     1.000000   1.000000      NaN
# 25%     1.250000   1.250000      NaN
# 50%     1.500000   1.500000      NaN
# 75%     1.750000   1.750000      NaN
# max     2.000000   2.000000      NaN

# %%
transactions.sample(5, random_state=12345)
# Out:
#              date  store_nbr  transactions
# 0      2013-01-01         25           770
# 1      2013-01-02          1          2111
# 2      2013-01-02          2          2358
# 3      2013-01-02          3          3487
# 4      2013-01-02          4          1922
# ...           ...        ...           ...
# 83483  2017-08-15         50          2804
# 83484  2017-08-15         51          1573
# 83485  2017-08-15         52          2255
# 83486  2017-08-15         53           932
# 83487  2017-08-15         54           802
#
# [83488 rows x 3 columns]
