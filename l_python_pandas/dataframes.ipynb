# %% [markdown]
# ### Dataframes
# - table of data ( series column)
# - row axis = 0
# - row axis = 1
# - shape, index, columns , axes , dtype

# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame(
    {"id": [1,2],
     "store_nbr":[1,2],
     "family" : ["POULTRY","PRODUCE"]
    })
df
# Out:
#    id  store_nbr   family
# 0   1          1  POULTRY
# 1   2          2  PRODUCE

# %%
print(f"shape : {df.shape}")
print(f"size : {df.size}")
print(f"index : {df.index}")
print(f"columns : {df.columns}")
print(f"dtypes : {df.dtypes}")
# Out:
# shape : (2, 3)
# size : 6
# index : RangeIndex(start=0, stop=2, step=1)
# columns : Index(['id', 'store_nbr', 'family'], dtype='object')
# dtypes : id            int64
# store_nbr     int64
# family       object
# dtype: object

# %%
retail_df = pd.read_csv("./retail/stores.csv")
retail_df
# Out:
#     store_nbr           city                           state type  cluster
# 0           1          Quito                       Pichincha    D       13
# 1           2          Quito                       Pichincha    D       13
# 2           3          Quito                       Pichincha    D        8
# 3           4          Quito                       Pichincha    D        9
# 4           5  Santo Domingo  Santo Domingo de los Tsachilas    D        4
# 5           6          Quito                       Pichincha    D       13
# 6           7          Quito                       Pichincha    D        8
# 7           8          Quito                       Pichincha    D        8
# 8           9          Quito                       Pichincha    B        6
# 9          10          Quito                       Pichincha    C       15
# 10         11        Cayambe                       Pichincha    B        6
# ...

# %%
oil = pd.read_csv("./retail/oil.csv")
oil
# Out:
#             date  dcoilwtico
# 0     2013-01-01         NaN
# 1     2013-01-02       93.14
# 2     2013-01-03       92.97
# 3     2013-01-04       93.12
# 4     2013-01-07       93.20
# ...          ...         ...
# 1213  2017-08-25       47.65
# 1214  2017-08-28       46.40
# 1215  2017-08-29       46.46
# 1216  2017-08-30       45.96
# 1217  2017-08-31       47.26
#
# [1218 rows x 2 columns]

# %%
oil.shape
# Out:
# (1218, 2)

# %%
oil.index
# Out:
# RangeIndex(start=0, stop=1218, step=1)

# %%
oil.columns
# Out:
# Index(['date', 'dcoilwtico'], dtype='object')

# %%
oil.columns = ['price_date', 'oil_prices']

# %%
oil
# Out:
#       price_date  oil_prices
# 0     2013-01-01         NaN
# 1     2013-01-02       93.14
# 2     2013-01-03       92.97
# 3     2013-01-04       93.12
# 4     2013-01-07       93.20
# ...          ...         ...
# 1213  2017-08-25       47.65
# 1214  2017-08-28       46.40
# 1215  2017-08-29       46.46
# 1216  2017-08-30       45.96
# 1217  2017-08-31       47.26
#
# [1218 rows x 2 columns]

# %%
oil.axes
# Out:
# [RangeIndex(start=0, stop=1218, step=1),
#  Index(['price_date', 'oil_prices'], dtype='object')]

# %%
oil.dtypes
# Out:
# price_date     object
# oil_prices    float64
# dtype: object

# %% [markdown]
# # Exercise 1

# %%
transactions = pd.read_csv("./retail/transactions.csv")

transactions
# Out:
#              date  store_nbr  transactions
# 0      2013-01-01         25           770
# 1      2013-01-02          1          2111
# 2      2013-01-02          2          2358
# 3      2013-01-02          3          3487
# 4      2013-01-02          4          1922
# ...           ...        ...           ...
# 83483  2017-08-15         50          2804
# 83484  2017-08-15         51          1573
# 83485  2017-08-15         52          2255
# 83486  2017-08-15         53           932
# 83487  2017-08-15         54           802
#
# [83488 rows x 3 columns]

# %%
# number of rows and columns 
transactions.shape
# Out:
# (83488, 3)

# %%
# name of the columns 
transactions.columns
# Out:
# Index(['date', 'store_nbr', 'transactions'], dtype='object')

# %%
transactions.dtypes
# Out:
# date            object
# store_nbr        int64
# transactions     int64
# dtype: object

# %% [markdown]
# # explore a dataframe

# %%
df.head()
# Out:
#    id  store_nbr   family
# 0   1          1  POULTRY
# 1   2          2  PRODUCE

# %%
df.tail()
# Out:
#    id  store_nbr   family
# 0   1          1  POULTRY
# 1   2          2  PRODUCE

# %%
df.sample()
# Out:
#    id  store_nbr   family
# 1   2          2  PRODUCE

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   id         2 non-null      int64
#  1   store_nbr  2 non-null      int64
#  2   family     2 non-null      object
# dtypes: int64(2), object(1)
# memory usage: 176.0+ bytes

# %%
df.describe()
# Out:
#              id  store_nbr
# count  2.000000   2.000000
# mean   1.500000   1.500000
# std    0.707107   0.707107
# min    1.000000   1.000000
# 25%    1.250000   1.250000
# 50%    1.500000   1.500000
# 75%    1.750000   1.750000
# max    2.000000   2.000000

# %%
df.describe(include = 'all')
# Out:
#               id  store_nbr   family
# count   2.000000   2.000000        2
# unique       NaN        NaN        2
# top          NaN        NaN  POULTRY
# freq         NaN        NaN        1
# mean    1.500000   1.500000      NaN
# std     0.707107   0.707107      NaN
# min     1.000000   1.000000      NaN
# 25%     1.250000   1.250000      NaN
# 50%     1.500000   1.500000      NaN
# 75%     1.750000   1.750000      NaN
# max     2.000000   2.000000      NaN

# %%
transactions.sample(5, random_state=12345)
# Out:
#              date  store_nbr  transactions
# 2695   2013-03-01         31          1325
# 56268  2016-03-17         11          2054
# 57041  2016-03-31         44          3716
# 79201  2017-05-28         34          2034
# 31296  2014-11-03         39          1359

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   id         2 non-null      int64
#  1   store_nbr  2 non-null      int64
#  2   family     2 non-null      object
# dtypes: int64(2), object(1)
# memory usage: 176.0+ bytes

# %%
transactions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 83488 entries, 0 to 83487
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date          83488 non-null  object
#  1   store_nbr     83488 non-null  int64
#  2   transactions  83488 non-null  int64
# dtypes: int64(2), object(1)
# memory usage: 1.9+ MB

# %%
transactions.info(show_counts=True) # more then 1.7 million rows
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 83488 entries, 0 to 83487
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date          83488 non-null  object
#  1   store_nbr     83488 non-null  int64
#  2   transactions  83488 non-null  int64
# dtypes: int64(2), object(1)
# memory usage: 1.9+ MB

# %%
transactions.describe()
# Out:
#           store_nbr  transactions
# count  83488.000000  83488.000000
# mean      26.939237   1694.602158
# std       15.608204    963.286644
# min        1.000000      5.000000
# 25%       13.000000   1046.000000
# 50%       27.000000   1393.000000
# 75%       40.000000   2079.000000
# max       54.000000   8359.000000

# %%
transactions.describe(include='all')
# Out:
#               date     store_nbr  transactions
# count        83488  83488.000000  83488.000000
# unique        1682           NaN           NaN
# top     2017-08-15           NaN           NaN
# freq            54           NaN           NaN
# mean           NaN     26.939237   1694.602158
# std            NaN     15.608204    963.286644
# min            NaN      1.000000      5.000000
# 25%            NaN     13.000000   1046.000000
# 50%            NaN     27.000000   1393.000000
# 75%            NaN     40.000000   2079.000000
# max            NaN     54.000000   8359.000000

# %%
oil
# Out:
#       price_date  oil_prices
# 0     2013-01-01         NaN
# 1     2013-01-02       93.14
# 2     2013-01-03       92.97
# 3     2013-01-04       93.12
# 4     2013-01-07       93.20
# ...          ...         ...
# 1213  2017-08-25       47.65
# 1214  2017-08-28       46.40
# 1215  2017-08-29       46.46
# 1216  2017-08-30       45.96
# 1217  2017-08-31       47.26
#
# [1218 rows x 2 columns]

# %%
oil.head(10)
# Out:
#    price_date  oil_prices
# 0  2013-01-01         NaN
# 1  2013-01-02       93.14
# 2  2013-01-03       92.97
# 3  2013-01-04       93.12
# 4  2013-01-07       93.20
# 5  2013-01-08       93.21
# 6  2013-01-09       93.08
# 7  2013-01-10       93.81
# 8  2013-01-11       93.60
# 9  2013-01-14       94.27

# %%
oil.tail(7)
# Out:
#       price_date  oil_prices
# 1211  2017-08-23       48.45
# 1212  2017-08-24       47.24
# 1213  2017-08-25       47.65
# 1214  2017-08-28       46.40
# 1215  2017-08-29       46.46
# 1216  2017-08-30       45.96
# 1217  2017-08-31       47.26

# %%
oil.sample(5)
# Out:
#      price_date  oil_prices
# 924  2016-07-18       45.23
# 648  2015-06-26       59.41
# 900  2016-06-14       48.49
# 489  2014-11-17       75.64
# 45   2013-03-05       90.88

# %%
oil.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1218 entries, 0 to 1217
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   price_date  1218 non-null   object
#  1   oil_prices  1175 non-null   float64
# dtypes: float64(1), object(1)
# memory usage: 19.2+ KB

# %%
oil.describe()
# Out:
#         oil_prices
# count  1175.000000
# mean     67.714366
# std      25.630476
# min      26.190000
# 25%      46.405000
# 50%      53.190000
# 75%      95.660000
# max     110.620000

# %%
oil.describe(include='all')
# Out:
#         price_date   oil_prices
# count         1218  1175.000000
# unique        1218          NaN
# top     2013-01-01          NaN
# freq             1          NaN
# mean           NaN    67.714366
# std            NaN    25.630476
# min            NaN    26.190000
# 25%            NaN    46.405000
# 50%            NaN    53.190000
# 75%            NaN    95.660000
# max            NaN   110.620000

# %% [markdown]
# ### Exercise 2

# %%
# first 5 rows 
transactions.head(5)
# Out:
#          date  store_nbr  transactions
# 0  2013-01-01         25           770
# 1  2013-01-02          1          2111
# 2  2013-01-02          2          2358
# 3  2013-01-02          3          3487
# 4  2013-01-02          4          1922

# %%
transactions.isna().sum()
# Out:
# date            0
# store_nbr       0
# transactions    0
# dtype: int64

# %%
transactions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 83488 entries, 0 to 83487
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date          83488 non-null  object
#  1   store_nbr     83488 non-null  int64
#  2   transactions  83488 non-null  int64
# dtypes: int64(2), object(1)
# memory usage: 1.9+ MB

# %%
transactions.describe()
# Out:
#           store_nbr  transactions
# count  83488.000000  83488.000000
# mean      26.939237   1694.602158
# std       15.608204    963.286644
# min        1.000000      5.000000
# 25%       13.000000   1046.000000
# 50%       27.000000   1393.000000
# 75%       40.000000   2079.000000
# max       54.000000   8359.000000

# %%
transactions.describe(include='all')
# Out:
#               date     store_nbr  transactions
# count        83488  83488.000000  83488.000000
# unique        1682           NaN           NaN
# top     2017-08-15           NaN           NaN
# freq            54           NaN           NaN
# mean           NaN     26.939237   1694.602158
# std            NaN     15.608204    963.286644
# min            NaN      1.000000      5.000000
# 25%            NaN     13.000000   1046.000000
# 50%            NaN     27.000000   1393.000000
# 75%            NaN     40.000000   2079.000000
# max            NaN     54.000000   8359.000000

# %%
transactions['transactions'].median()
# Out:
# np.float64(1393.0)

# %% [markdown]
# ### Accessing dataframe columns

# %%
transactions['transactions']
# Out:
# 0         770
# 1        2111
# 2        2358
# 3        3487
# 4        1922
#          ...
# 83483    2804
# 83484    1573
# 83485    2255
# 83486     932
# 83487     802
# Name: transactions, Length: 83488, dtype: int64

# %%
transactions.transactions
# Out:
# 0         770
# 1        2111
# 2        2358
# 3        3487
# 4        1922
#          ...
# 83483    2804
# 83484    1573
# 83485    2255
# 83486     932
# 83487     802
# Name: transactions, Length: 83488, dtype: int64

# %%
# use series operations on dataframe columns
transactions.head()
# Out:
#          date  store_nbr  transactions
# 0  2013-01-01         25           770
# 1  2013-01-02          1          2111
# 2  2013-01-02          2          2358
# 3  2013-01-02          3          3487
# 4  2013-01-02          4          1922

# %%
df
# Out:
#    id  store_nbr   family
# 0   1          1  POULTRY
# 1   2          2  PRODUCE

# %%
df["id"].nunique()
# Out:
# 2

# %%
df["store_nbr"].mean()
# Out:
# np.float64(1.5)

# %%
df["store_nbr"].value_counts().iloc[:1]
# Out:
# store_nbr
# 1    1
# Name: count, dtype: int64

# %%
df["store_nbr"].sum()
# Out:
# np.int64(3)

# %%
# select multiple columns
df[['id','store_nbr']]
# Out:
#    id  store_nbr
# 0   1          1
# 1   2          2

# %%
df[['id','store_nbr']].iloc[:1]
# Out:
#    id  store_nbr
# 0   1          1

# %%
oil.head()
# Out:
#    price_date  oil_prices
# 0  2013-01-01         NaN
# 1  2013-01-02       93.14
# 2  2013-01-03       92.97
# 3  2013-01-04       93.12
# 4  2013-01-07       93.20

# %% [markdown]
# ### accessing data with iloc

# %%
transactions.iloc[:5,:] # positional index
# Out:
#          date  store_nbr  transactions
# 0  2013-01-01         25           770
# 1  2013-01-02          1          2111
# 2  2013-01-02          2          2358
# 3  2013-01-02          3          3487
# 4  2013-01-02          4          1922

# %%
transactions.iloc[:,1:2]
# Out:
#        store_nbr
# 0             25
# 1              1
# 2              2
# 3              3
# 4              4
# ...          ...
# 83483         50
# 83484         51
# 83485         52
# 83486         53
# 83487         54
#
# [83488 rows x 1 columns]

# %%
transactions.loc[:, "date"] # returns series
# Out:
# 0        2013-01-01
# 1        2013-01-02
# 2        2013-01-02
# 3        2013-01-02
# 4        2013-01-02
#             ...
# 83483    2017-08-15
# 83484    2017-08-15
# 83485    2017-08-15
# 83486    2017-08-15
# 83487    2017-08-15
# Name: date, Length: 83488, dtype: object

# %%
transactions.loc[:, ["date"]] # returns dataframe
# Out:
#              date
# 0      2013-01-01
# 1      2013-01-02
# 2      2013-01-02
# 3      2013-01-02
# 4      2013-01-02
# ...           ...
# 83483  2017-08-15
# 83484  2017-08-15
# 83485  2017-08-15
# 83486  2017-08-15
# 83487  2017-08-15
#
# [83488 rows x 1 columns]

# %%
transactions.loc[:, ["date", "store_nbr"]]
# Out:
#              date  store_nbr
# 0      2013-01-01         25
# 1      2013-01-02          1
# 2      2013-01-02          2
# 3      2013-01-02          3
# 4      2013-01-02          4
# ...           ...        ...
# 83483  2017-08-15         50
# 83484  2017-08-15         51
# 83485  2017-08-15         52
# 83486  2017-08-15         53
# 83487  2017-08-15         54
#
# [83488 rows x 2 columns]

# %%
transactions.loc[:, "date": "store_nbr"]
# Out:
#              date  store_nbr
# 0      2013-01-01         25
# 1      2013-01-02          1
# 2      2013-01-02          2
# 3      2013-01-02          3
# 4      2013-01-02          4
# ...           ...        ...
# 83483  2017-08-15         50
# 83484  2017-08-15         51
# 83485  2017-08-15         52
# 83486  2017-08-15         53
# 83487  2017-08-15         54
#
# [83488 rows x 2 columns]

# %%
oil
# Out:
#       price_date  oil_prices
# 0     2013-01-01         NaN
# 1     2013-01-02       93.14
# 2     2013-01-03       92.97
# 3     2013-01-04       93.12
# 4     2013-01-07       93.20
# ...          ...         ...
# 1213  2017-08-25       47.65
# 1214  2017-08-28       46.40
# 1215  2017-08-29       46.46
# 1216  2017-08-30       45.96
# 1217  2017-08-31       47.26
#
# [1218 rows x 2 columns]

# %%
oil.columns = ['date','price']

oil['euro_price'] = oil['price'] * 1.1

oil.head()
# Out:
#          date  price  euro_price
# 0  2013-01-01    NaN         NaN
# 1  2013-01-02  93.14     102.454
# 2  2013-01-03  92.97     102.267
# 3  2013-01-04  93.12     102.432
# 4  2013-01-07  93.20     102.520

# %%
oil.iloc[:10,:]
# Out:
#          date  price  euro_price
# 0  2013-01-01    NaN         NaN
# 1  2013-01-02  93.14     102.454
# 2  2013-01-03  92.97     102.267
# 3  2013-01-04  93.12     102.432
# 4  2013-01-07  93.20     102.520
# 5  2013-01-08  93.21     102.531
# 6  2013-01-09  93.08     102.388
# 7  2013-01-10  93.81     103.191
# 8  2013-01-11  93.60     102.960
# 9  2013-01-14  94.27     103.697

# %%
oil.iloc[:10,-2:]
# Out:
#    price  euro_price
# 0    NaN         NaN
# 1  93.14     102.454
# 2  92.97     102.267
# 3  93.12     102.432
# 4  93.20     102.520
# 5  93.21     102.531
# 6  93.08     102.388
# 7  93.81     103.191
# 8  93.60     102.960
# 9  94.27     103.697

# %%
oil.loc[:5,['date','euro_price']] # inclusive in loc but not in iloc
# Out:
#          date  euro_price
# 0  2013-01-01         NaN
# 1  2013-01-02     102.454
# 2  2013-01-03     102.267
# 3  2013-01-04     102.432
# 4  2013-01-07     102.520
# 5  2013-01-08     102.531

# %%
oil.loc[:5,['euro_price','date']]
# Out:
#    euro_price        date
# 0         NaN  2013-01-01
# 1     102.454  2013-01-02
# 2     102.267  2013-01-03
# 3     102.432  2013-01-04
# 4     102.520  2013-01-07
# 5     102.531  2013-01-08

# %% [markdown]
# ### Exercise 3

# %%
transactions
# Out:
#              date  store_nbr  transactions
# 0      2013-01-01         25           770
# 1      2013-01-02          1          2111
# 2      2013-01-02          2          2358
# 3      2013-01-02          3          3487
# 4      2013-01-02          4          1922
# ...           ...        ...           ...
# 83483  2017-08-15         50          2804
# 83484  2017-08-15         51          1573
# 83485  2017-08-15         52          2255
# 83486  2017-08-15         53           932
# 83487  2017-08-15         54           802
#
# [83488 rows x 3 columns]

# %%
transactions.loc[1:, ['store_nbr','transactions']]
# Out:
#        store_nbr  transactions
# 1              1          2111
# 2              2          2358
# 3              3          3487
# 4              4          1922
# 5              5          1903
# ...          ...           ...
# 83483         50          2804
# 83484         51          1573
# 83485         52          2255
# 83486         53           932
# 83487         54           802
#
# [83487 rows x 2 columns]

# %%
transactions['store_nbr'].nunique()
# Out:
# 54

# %%
transactions['transactions'].sum()/1000000
# Out:
# np.float64(141.478945)

# %% [markdown]
# ### dropping rows and columns in dataframe
# .drop() axis=0 rows , axis=1 columns
#
# df.drop("id", axis=1).head() -- remove column id
#
# df.drop(["id","onpromotion"], inplace=True, axis=1)
# df.head() -- cal coz of inplace will permanently drop and free up memory
#
# +++++
# df.drop([0], axis=0).head()
# df.drop(range(5), axis=0).head() --- you can do inplace

# %%
oil.head()
# Out:
#          date  price  euro_price
# 0  2013-01-01    NaN         NaN
# 1  2013-01-02  93.14     102.454
# 2  2013-01-03  92.97     102.267
# 3  2013-01-04  93.12     102.432
# 4  2013-01-07  93.20     102.520

# %%
oil_euro = oil.drop('price', axis=1)

# %%
oil.head()
# Out:
#          date  price  euro_price
# 0  2013-01-01    NaN         NaN
# 1  2013-01-02  93.14     102.454
# 2  2013-01-03  92.97     102.267
# 3  2013-01-04  93.12     102.432
# 4  2013-01-07  93.20     102.520

# %%
oil_euro.head()
# Out:
#          date  euro_price
# 0  2013-01-01         NaN
# 1  2013-01-02     102.454
# 2  2013-01-03     102.267
# 3  2013-01-04     102.432
# 4  2013-01-07     102.520

# %%
oil_euro = oil.drop(1, axis=0) # drop row

# %%
oil_euro.head()
# Out:
#          date  price  euro_price
# 0  2013-01-01    NaN         NaN
# 2  2013-01-03  92.97     102.267
# 3  2013-01-04  93.12     102.432
# 4  2013-01-07  93.20     102.520
# 5  2013-01-08  93.21     102.531

# %%
oil_euro.reset_index()
# Out:
#       index        date  price  euro_price
# 0         0  2013-01-01    NaN         NaN
# 1         2  2013-01-03  92.97     102.267
# 2         3  2013-01-04  93.12     102.432
# 3         4  2013-01-07  93.20     102.520
# 4         5  2013-01-08  93.21     102.531
# ...     ...         ...    ...         ...
# 1212   1213  2017-08-25  47.65      52.415
# 1213   1214  2017-08-28  46.40      51.040
# 1214   1215  2017-08-29  46.46      51.106
# 1215   1216  2017-08-30  45.96      50.556
# 1216   1217  2017-08-31  47.26      51.986
#
# [1217 rows x 4 columns]

# %% [markdown]
# ### duplicate()
# df.duplicate()
# df.duplicate(subset='price')
# df.drop_duplicate()
# df.drop_duplicate(subset='product',keep='last',ignore_index=True)

# %%
oil.tail()
# Out:
#             date  price  euro_price
# 1213  2017-08-25  47.65      52.415
# 1214  2017-08-28  46.40      51.040
# 1215  2017-08-29  46.46      51.106
# 1216  2017-08-30  45.96      50.556
# 1217  2017-08-31  47.26      51.986

# %%
oil.shape
# Out:
# (1218, 3)

# %%
transactions
# Out:
#              date  store_nbr  transactions
# 0      2013-01-01         25           770
# 1      2013-01-02          1          2111
# 2      2013-01-02          2          2358
# 3      2013-01-02          3          3487
# 4      2013-01-02          4          1922
# ...           ...        ...           ...
# 83483  2017-08-15         50          2804
# 83484  2017-08-15         51          1573
# 83485  2017-08-15         52          2255
# 83486  2017-08-15         53           932
# 83487  2017-08-15         54           802
#
# [83488 rows x 3 columns]

# %%
oil.nunique(dropna=False)
# Out:
# date          1218
# price          999
# euro_price     999
# dtype: int64

# %%
oil.duplicated(subset='price').sum()
# Out:
# np.int64(219)

# %%
oil
# Out:
#             date  price  euro_price
# 0     2013-01-01    NaN         NaN
# 1     2013-01-02  93.14     102.454
# 2     2013-01-03  92.97     102.267
# 3     2013-01-04  93.12     102.432
# 4     2013-01-07  93.20     102.520
# ...          ...    ...         ...
# 1213  2017-08-25  47.65      52.415
# 1214  2017-08-28  46.40      51.040
# 1215  2017-08-29  46.46      51.106
# 1216  2017-08-30  45.96      50.556
# 1217  2017-08-31  47.26      51.986
#
# [1218 rows x 3 columns]

# %%
oil.drop_duplicates()
# Out:
#             date  price  euro_price
# 0     2013-01-01    NaN         NaN
# 1     2013-01-02  93.14     102.454
# 2     2013-01-03  92.97     102.267
# 3     2013-01-04  93.12     102.432
# 4     2013-01-07  93.20     102.520
# ...          ...    ...         ...
# 1213  2017-08-25  47.65      52.415
# 1214  2017-08-28  46.40      51.040
# 1215  2017-08-29  46.46      51.106
# 1216  2017-08-30  45.96      50.556
# 1217  2017-08-31  47.26      51.986
#
# [1218 rows x 3 columns]

# %%
oil.drop_duplicates(keep='last')
# Out:
#             date  price  euro_price
# 0     2013-01-01    NaN         NaN
# 1     2013-01-02  93.14     102.454
# 2     2013-01-03  92.97     102.267
# 3     2013-01-04  93.12     102.432
# 4     2013-01-07  93.20     102.520
# ...          ...    ...         ...
# 1213  2017-08-25  47.65      52.415
# 1214  2017-08-28  46.40      51.040
# 1215  2017-08-29  46.46      51.106
# 1216  2017-08-30  45.96      50.556
# 1217  2017-08-31  47.26      51.986
#
# [1218 rows x 3 columns]

# %%
oil.drop_duplicates(keep='last', ignore_index=True)
# Out:
#             date  price  euro_price
# 0     2013-01-01    NaN         NaN
# 1     2013-01-02  93.14     102.454
# 2     2013-01-03  92.97     102.267
# 3     2013-01-04  93.12     102.432
# 4     2013-01-07  93.20     102.520
# ...          ...    ...         ...
# 1213  2017-08-25  47.65      52.415
# 1214  2017-08-28  46.40      51.040
# 1215  2017-08-29  46.46      51.106
# 1216  2017-08-30  45.96      50.556
# 1217  2017-08-31  47.26      51.986
#
# [1218 rows x 3 columns]

# %%
oil.drop_duplicates(subset=['price'] , keep='last', ignore_index=True)
# Out:
#            date  price  euro_price
# 0    2013-01-02  93.14     102.454
# 1    2013-01-03  92.97     102.267
# 2    2013-01-07  93.20     102.520
# 3    2013-01-09  93.08     102.388
# 4    2013-01-14  94.27     103.697
# ..          ...    ...         ...
# 994  2017-08-25  47.65      52.415
# 995  2017-08-28  46.40      51.040
# 996  2017-08-29  46.46      51.106
# 997  2017-08-30  45.96      50.556
# 998  2017-08-31  47.26      51.986
#
# [999 rows x 3 columns]

# %% [markdown]
# ### Exercise 4
# # drop the first row , slice for viewing , permanently removed
# # drop the date but not in place
# # get df that included only last row for each of the stores

# %%
transaction2 = transactions
transaction2
# Out:
#              date  store_nbr  transactions
# 0      2013-01-01         25           770
# 1      2013-01-02          1          2111
# 2      2013-01-02          2          2358
# 3      2013-01-02          3          3487
# 4      2013-01-02          4          1922
# ...           ...        ...           ...
# 83483  2017-08-15         50          2804
# 83484  2017-08-15         51          1573
# 83485  2017-08-15         52          2255
# 83486  2017-08-15         53           932
# 83487  2017-08-15         54           802
#
# [83488 rows x 3 columns]

# %%
transaction2.drop(0, axis=0, inplace=True)
transaction2.head()
# Out:
#          date  store_nbr  transactions
# 1  2013-01-02          1          2111
# 2  2013-01-02          2          2358
# 3  2013-01-02          3          3487
# 4  2013-01-02          4          1922
# 5  2013-01-02          5          1903

# %%
transactions.drop('date', axis=1).head()
# Out:
#    store_nbr  transactions
# 1          1          2111
# 2          2          2358
# 3          3          3487
# 4          4          1922
# 5          5          1903

# %%
transactions.drop_duplicates(subset='store_nbr', keep='last').head()
# Out:
#              date  store_nbr  transactions
# 83434  2017-08-15          1          1693
# 83435  2017-08-15          2          1737
# 83436  2017-08-15          3          2956
# 83437  2017-08-15          4          1283
# 83438  2017-08-15          5          1310

# %% [markdown]
# ### handling missing values same as series with some more options
# - drop , fillna
# - .fillna({'price':0}) , .dropna(subset=['price'] ) -- default is all 0

# %% [markdown]
# ### Exercise 6

# %%
oil = pd.read_csv('./retail/oil.csv')
oil.head()
# Out:
#          date  dcoilwtico
# 0  2013-01-01         NaN
# 1  2013-01-02       93.14
# 2  2013-01-03       92.97
# 3  2013-01-04       93.12
# 4  2013-01-07       93.20

# %%
# can you tell if any date or price are missing ?
oil.info() # date not missing but dcoilwtico has missing values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1218 entries, 0 to 1217
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        1218 non-null   object
#  1   dcoilwtico  1175 non-null   float64
# dtypes: float64(1), object(1)
# memory usage: 19.2+ KB

# %%
oil.isna().sum()
# Out:
# date           0
# dcoilwtico    43
# dtype: int64

# %%
# compare mean prices by filling with 0 and mean
oil['dcoilwtico'].fillna(0).mean()
# Out:
# np.float64(65.32379310344828)

# %%
oil.loc[:,'dcoilwtico'].fillna(0).mean()
# Out:
# np.float64(65.32379310344828)

# %%
oil['dcoilwtico'].fillna({'dcoilwtico':oil['dcoilwtico'].mean()}).mean()
# Out:
# np.float64(67.71436595744682)

# %% [markdown]
# ### filtering dataframes
# filter the rows retail_df.loc[retail_df["date"]=="2016-10-28"]
# -- filter the rows and select the columns , retail_df.loc[retail_df["date"]== "2016-10-28",["date","sales"]].head()
# -- apply multiple filters using &
# conds = retail_df["family"].isin(["cleaning","dairy"]) & (retail_df["sales"] > 0)

# %%
oil.head()
# Out:
#          date  dcoilwtico
# 0  2013-01-01         NaN
# 1  2013-01-02       93.14
# 2  2013-01-03       92.97
# 3  2013-01-04       93.12
# 4  2013-01-07       93.20

# %%
oil.describe()
# Out:
#         dcoilwtico
# count  1175.000000
# mean     67.714366
# std      25.630476
# min      26.190000
# 25%      46.405000
# 50%      53.190000
# 75%      95.660000
# max     110.620000

# %%
oil.loc[oil['dcoilwtico']> 100]
# Out:
#            date  dcoilwtico
# 131  2013-07-03      101.92
# 133  2013-07-05      103.09
# 134  2013-07-08      103.03
# 135  2013-07-09      103.46
# 136  2013-07-10      106.41
# ..          ...         ...
# 407  2014-07-24      102.76
# 408  2014-07-25      105.23
# 409  2014-07-28      105.68
# 410  2014-07-29      104.91
# 411  2014-07-30      104.29
#
# [182 rows x 2 columns]

# %%
oil.loc[oil['dcoilwtico'] > 100, ['date']] # selects only date
# Out:
#            date
# 131  2013-07-03
# 133  2013-07-05
# 134  2013-07-08
# 135  2013-07-09
# 136  2013-07-10
# ..          ...
# 407  2014-07-24
# 408  2014-07-25
# 409  2014-07-28
# 410  2014-07-29
# 411  2014-07-30
#
# [182 rows x 1 columns]

# %%
# modifies values safely 
oil.loc[oil['dcoilwtico'] > 100, 'dcoilwtico'] = 99

# %%
oil.loc[oil['date'].str[:4] == '2013']
# Out:
#            date  dcoilwtico
# 0    2013-01-01         NaN
# 1    2013-01-02       93.14
# 2    2013-01-03       92.97
# 3    2013-01-04       93.12
# 4    2013-01-07       93.20
# ..          ...         ...
# 256  2013-12-25         NaN
# 257  2013-12-26       99.18
# 258  2013-12-27       99.94
# 259  2013-12-30       98.90
# 260  2013-12-31       98.17
#
# [261 rows x 2 columns]

# %%
mask = ((oil['dcoilwtico']> 100) | (oil['date'].str[:4] == '2013'))

# %%
oil.loc[mask]
# Out:
#            date  dcoilwtico
# 0    2013-01-01         NaN
# 1    2013-01-02       93.14
# 2    2013-01-03       92.97
# 3    2013-01-04       93.12
# 4    2013-01-07       93.20
# ..          ...         ...
# 407  2014-07-24      102.76
# 408  2014-07-25      105.23
# 409  2014-07-28      105.68
# 410  2014-07-29      104.91
# 411  2014-07-30      104.29
#
# [367 rows x 2 columns]

# %% [markdown]
# # .query() method lets you use SQL - like syntax to filter df
# retail_df.query("family in ['CLEANING', 'DAIRY'] and sales > 0")
# - reference variables using @ symbol
# - avg_sales = retail_df.loc[:,"sales"].mean()
# - retail_df.query("family in ['CLEANING', 'DAIRY'] and sales > @avg_sales")

# %%
oil.dtypes
# Out:
# date           object
# dcoilwtico    float64
# dtype: object

# %%
oil.dtypes
# Out:
# date           object
# dcoilwtico    float64
# dtype: object

# %%
oil = pd.read_csv('./retail/oil.csv',
                 parse_dates=['date']
                 )
oil['benchmark'] = 100
oil.head()
# Out:
#         date  dcoilwtico  benchmark
# 0 2013-01-01         NaN        100
# 1 2013-01-02       93.14        100
# 2 2013-01-03       92.97        100
# 3 2013-01-04       93.12        100
# 4 2013-01-07       93.20        100

# %%
oil.dtypes
# Out:
# date          datetime64[ns]
# dcoilwtico           float64
# benchmark              int64
# dtype: object

# %%
oil.query("dcoilwtico > benchmark or date.dt.year == 2013")
# Out:
#           date  dcoilwtico  benchmark
# 0   2013-01-01         NaN        100
# 1   2013-01-02       93.14        100
# 2   2013-01-03       92.97        100
# 3   2013-01-04       93.12        100
# 4   2013-01-07       93.20        100
# ..         ...         ...        ...
# 407 2014-07-24      102.76        100
# 408 2014-07-25      105.23        100
# 409 2014-07-28      105.68        100
# 410 2014-07-29      104.91        100
# 411 2014-07-30      104.29        100
#
# [367 rows x 3 columns]

# %% [markdown]
# ### Exercise 6
# transactions
# - calculate % of times ALL stores had more than 2000 transactions
# - cal the % of times store 25 had more than 2000 tx, and calculate the sum of txn on these days
# - sum the txn for stores 25 and 31 , that occured in May or June , and had less than 2000 txns

# %%
transactions = pd.read_csv('./retail/transactions.csv')
transactions.head()
# Out:
#          date  store_nbr  transactions
# 0  2013-01-01         25           770
# 1  2013-01-02          1          2111
# 2  2013-01-02          2          2358
# 3  2013-01-02          3          3487
# 4  2013-01-02          4          1922

# %%
transactions.query("date.str[6]=='1'")
# Out:
#              date  store_nbr  transactions
# 0      2013-01-01         25           770
# 1      2013-01-02          1          2111
# 2      2013-01-02          2          2358
# 3      2013-01-02          3          3487
# 4      2013-01-02          4          1922
# ...           ...        ...           ...
# 72977  2017-01-31         49          2680
# 72978  2017-01-31         50          2158
# 72979  2017-01-31         51          1448
# 72980  2017-01-31         53           950
# 72981  2017-01-31         54           793
#
# [13301 rows x 3 columns]

# %%
#calculate % of times ALL stores had more than 2000 transactions
transactions.query("transactions > 2000")
# Out:
#              date  store_nbr  transactions
# 1      2013-01-02          1          2111
# 2      2013-01-02          2          2358
# 3      2013-01-02          3          3487
# 6      2013-01-02          6          2143
# 8      2013-01-02          8          3250
# ...           ...        ...           ...
# 83480  2017-08-15         47          3581
# 83481  2017-08-15         48          2722
# 83482  2017-08-15         49          2814
# 83483  2017-08-15         50          2804
# 83485  2017-08-15         52          2255
#
# [22275 rows x 3 columns]

# %%
(transactions['transactions'] > 2000).mean()
# Out:
# np.float64(0.26680481027213493)

# %%
#transactions.loc[transactions['transactions'] > 2000, 'transactions'].mean()

# %%
#transactions.count()

# %%
#transactions.loc[transactions['transactions'] > 2000, 'transactions'].count()

# %%
cal the % of times store 25 had more than 2000 tx, and calculate the sum of txn on these days

# %%
#transactions.query("transactions > 2000 & store_nbr==25 ").count()

# %%
#56/83488 * 100

# %%
tx = transactions.query("transactions > 2000 & store_nbr==25 ")

# %%
tx.count()/transactions.count() *100
# Out:
# date            0.067076
# store_nbr       0.067076
# transactions    0.067076
# dtype: float64

# %%
mask = (transactions["store_nbr"]==25) & (transactions["transactions"]>2000)

(transactions.loc[mask].count()
 /transactions.loc[transactions["store_nbr"]==25].count()
 ).iloc[2]
# Out:
# np.float64(0.0346749226006192)

# %%
(transactions.loc[mask, "transactions"].count()
 / transactions.loc[transactions["store_nbr"]==25, "transactions"].count()
)* 100
# Out:
# np.float64(3.4674922600619196)

# %%
tx['transactions'].sum()
# Out:
# np.int64(144903)

# %%
tx2 = transactions.query("transactions < 2000 & store_nbr in (25,31) & date.str[6] in ('5','6')")

# %%
tx2['transactions'].sum()
# Out:
# np.int64(644910)
