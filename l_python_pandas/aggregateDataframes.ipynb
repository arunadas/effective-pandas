# %%
import pandas as pd
retail = pd.read_csv("./retail/retail_2016_2017.csv")
retail.head()
# Out:
#         id        date  store_nbr      family  sales  onpromotion
# 0  1945944  2016-01-01          1  AUTOMOTIVE    0.0            0
# 1  1945945  2016-01-01          1   BABY CARE    0.0            0
# 2  1945946  2016-01-01          1      BEAUTY    0.0            0
# 3  1945947  2016-01-01          1   BEVERAGES    0.0            0
# 4  1945948  2016-01-01          1       BOOKS    0.0            0

# %%
retail.loc[:,['sales','onpromotion']].sample(100).sum().round(2)
# Out:
# sales          47253.53
# onpromotion      813.00
# dtype: float64

# %%
retail.loc[:,['sales','onpromotion']].sample(100).mean().round(2)
# Out:
# sales          385.98
# onpromotion      3.58
# dtype: float64

# %%
retail.loc[:,['sales','onpromotion']].mean()
# Out:
# sales          457.722487
# onpromotion      5.937977
# dtype: float64

# %%
retail.loc[:,['sales','onpromotion']].std()
# Out:
# sales          1317.154845
# onpromotion      18.086321
# dtype: float64

# %% [markdown]
# ### Grouping dataframes

# %%
retail.head()
# Out:
#         id        date  store_nbr      family  sales  onpromotion
# 0  1945944  2016-01-01          1  AUTOMOTIVE    0.0            0
# 1  1945945  2016-01-01          1   BABY CARE    0.0            0
# 2  1945946  2016-01-01          1      BEAUTY    0.0            0
# 3  1945947  2016-01-01          1   BEVERAGES    0.0            0
# 4  1945948  2016-01-01          1       BOOKS    0.0            0

# %%
retail.groupby('family')['sales'].sum().head()
# Out:
# family
# AUTOMOTIVE       226139.0
# BABY CARE          7903.0
# BEAUTY           166189.0
# BEVERAGES     105700279.0
# BOOKS              6438.0
# Name: sales, dtype: float64

# %%
retail.groupby('family')[['sales']].sum().head() ## double brackets returen dataframe
# Out:
#                   sales
# family
# AUTOMOTIVE     226139.0
# BABY CARE        7903.0
# BEAUTY         166189.0
# BEVERAGES   105700279.0
# BOOKS            6438.0

# %%
retail.groupby('family')[['sales']].mean().sort_values('sales', ascending=False)
# Out:
#                                   sales
# family
# GROCERY I                   4480.338968
# BEVERAGES                   3306.440159
# PRODUCE                     2299.909514
# CLEANING                    1192.684653
# DAIRY                        889.104511
# BREAD/BAKERY                 534.690257
# POULTRY                      387.135622
# MEATS                        361.343401
# PERSONAL CARE                318.871778
# DELI                         300.856381
# HOME CARE                    293.847472
# EGGS                         189.385729
# FROZEN FOODS                 161.930166
# PREPARED FOODS               103.479924
# LIQUOR,WINE,BEER              94.052271
# HOME AND KITCHEN I            30.963338
# HOME AND KITCHEN II           27.721784
# SEAFOOD                       22.808709
# GROCERY II                    22.714120
# CELEBRATION                   13.917073
# LADIESWEAR                    11.531657
# PLAYERS AND ELECTRONICS       10.608515
# ...

# %% [markdown]
# ### Exercise 1 top stores by transactions
# -- return top 10 stores by total tx in data

# %%
transactions = pd.read_csv("./retail/transactions.csv", parse_dates=["date"])
transactions.head()
# Out:
#         date  store_nbr  transactions
# 0 2013-01-01         25           770
# 1 2013-01-02          1          2111
# 2 2013-01-02          2          2358
# 3 2013-01-02          3          3487
# 4 2013-01-02          4          1922

# %%
transactions.groupby('store_nbr')[['transactions']].sum().sort_values('transactions',ascending=False).iloc[:10]
#retail.groupby('family')[['sales']].mean().sort_values('sales', ascending=False)
# Out:
#            transactions
# store_nbr
# 44              7273093
# 47              6535810
# 45              6201115
# 46              5990113
# 3               5366350
# 48              5107785
# 8               4637971
# 49              4574103
# 50              4384444
# 11              3972488

# %%
transactions.groupby(['store_nbr'])['transactions'].sum().sort_values(ascending=False).iloc[:10] # series
# Out:
# store_nbr
# 44    7273093
# 47    6535810
# 45    6201115
# 46    5990113
# 3     5366350
# 48    5107785
# 8     4637971
# 49    4574103
# 50    4384444
# 11    3972488
# Name: transactions, dtype: int64

# %% [markdown]
# ### multiple columns group by

# %%
retail.groupby(['family','store_nbr'])[['sales']].sum()
# Out:
#                              sales
# family     store_nbr
# AUTOMOTIVE 1           2524.000000
#            2           3918.000000
#            3           6790.000000
#            4           2565.000000
#            5           3667.000000
# ...                            ...
# SEAFOOD    50         12773.966999
#            51         34250.948976
#            52          1219.475999
#            53          3745.180001
#            54          1082.000000
#
# [1782 rows x 1 columns]

# %%
retail.groupby(['family','store_nbr'],
              as_index=False)[['sales']].sum()
# Out:
#           family  store_nbr         sales
# 0     AUTOMOTIVE          1   2524.000000
# 1     AUTOMOTIVE          2   3918.000000
# 2     AUTOMOTIVE          3   6790.000000
# 3     AUTOMOTIVE          4   2565.000000
# 4     AUTOMOTIVE          5   3667.000000
# ...          ...        ...           ...
# 1777     SEAFOOD         50  12773.966999
# 1778     SEAFOOD         51  34250.948976
# 1779     SEAFOOD         52   1219.475999
# 1780     SEAFOOD         53   3745.180001
# 1781     SEAFOOD         54   1082.000000
#
# [1782 rows x 3 columns]

# %%
retail.groupby(['family','store_nbr'],
              as_index=False)[['sales']].sum().query("family=='SEAFOOD'")
# Out:
#        family  store_nbr         sales
# 1728  SEAFOOD          1  15898.003002
# 1729  SEAFOOD          2  21453.224996
# 1730  SEAFOOD          3  60799.703097
# 1731  SEAFOOD          4  19222.407985
# 1732  SEAFOOD          5   6751.715996
# 1733  SEAFOOD          6  27767.546987
# 1734  SEAFOOD          7  32790.004997
# 1735  SEAFOOD          8  30746.884018
# 1736  SEAFOOD          9  10363.489010
# 1737  SEAFOOD         10   1865.000000
# 1738  SEAFOOD         11   6017.000000
# 1739  SEAFOOD         12   2743.000000
# 1740  SEAFOOD         13   1517.000000
# 1741  SEAFOOD         14   3099.000000
# 1742  SEAFOOD         15   3235.000000
# 1743  SEAFOOD         16    930.000000
# 1744  SEAFOOD         17   8133.462000
# 1745  SEAFOOD         18   5579.008001
# 1746  SEAFOOD         19   2998.000000
# 1747  SEAFOOD         20   8251.176989
# 1748  SEAFOOD         21   3389.000000
# 1749  SEAFOOD         22   1274.000000
# 1750  SEAFOOD         23   8249.763009
# ...

# %% [markdown]
# ### Exercise 2 group by multiple columns
# - txn by store and month
# - sort table from first month to last month , then by tx from highest to lowest within each month

# %%
transactions["month"] = transactions["date"].dt.month

transactions.head()
# Out:
#         date  store_nbr  transactions  month
# 0 2013-01-01         25           770      1
# 1 2013-01-02          1          2111      1
# 2 2013-01-02          2          2358      1
# 3 2013-01-02          3          3487      1
# 4 2013-01-02          4          1922      1

# %%
transactions.groupby(['store_nbr','month'],
                    as_index=False)[['transactions']].sum().sort_values(['month','transactions'],ascending=[True,False])
# Out:
#      store_nbr  month  transactions
# 516         44      1        628438
# 552         47      1        568824
# 528         45      1        538370
# 540         46      1        522763
# 24           3      1        463260
# ..         ...    ...           ...
# 383         32     12         86167
# 251         21     12         84128
# 503         42     12         76741
# 347         29     12         76627
# 263         22     12         50650
#
# [641 rows x 3 columns]

# %%
(transactions
 .groupby(['store_nbr','month'],)[['transactions']]
 .sum()
 .sort_values(['month','transactions'],ascending=[True,False])
)
# Out:
#                  transactions
# store_nbr month
# 44        1            628438
# 47        1            568824
# 45        1            538370
# 46        1            522763
# 3         1            463260
# ...                       ...
# 32        12            86167
# 21        12            84128
# 42        12            76741
# 29        12            76627
# 22        12            50650
#
# [641 rows x 1 columns]

# %% [markdown]
# ### Multi index dataframes

# %%
retail.groupby(['family','store_nbr'])[['sales']].sum()
# Out:
#                              sales
# family     store_nbr
# AUTOMOTIVE 1           2524.000000
#            2           3918.000000
#            3           6790.000000
#            4           2565.000000
#            5           3667.000000
# ...                            ...
# SEAFOOD    50         12773.966999
#            51         34250.948976
#            52          1219.475999
#            53          3745.180001
#            54          1082.000000
#
# [1782 rows x 1 columns]

# %%
retail.groupby(['family','store_nbr'])[['sales']].sum().loc['AUTOMOTIVE'].head()
# Out:
#             sales
# store_nbr
# 1          2524.0
# 2          3918.0
# 3          6790.0
# 4          2565.0
# 5          3667.0

# %%
retail.groupby(['family','store_nbr'])[['sales']].sum().loc["AUTOMOTIVE":"BEAUTY"]
# Out:
#                        sales
# family     store_nbr
# AUTOMOTIVE 1          2524.0
#            2          3918.0
#            3          6790.0
#            4          2565.0
#            5          3667.0
# ...                      ...
# BEAUTY     50         6353.0
#            51         3566.0
#            52          972.0
#            53         3812.0
#            54          405.0
#
# [162 rows x 1 columns]

# %%
print(retail.groupby(['family', 'store_nbr'])[['sales']].sum().index)
# Out:
# MultiIndex([('AUTOMOTIVE',  1),
#             ('AUTOMOTIVE',  2),
#             ('AUTOMOTIVE',  3),
#             ('AUTOMOTIVE',  4),
#             ('AUTOMOTIVE',  5),
#             ('AUTOMOTIVE',  6),
#             ('AUTOMOTIVE',  7),
#             ('AUTOMOTIVE',  8),
#             ('AUTOMOTIVE',  9),
#             ('AUTOMOTIVE', 10),
#             ...
#             (   'SEAFOOD', 45),
#             (   'SEAFOOD', 46),
#             (   'SEAFOOD', 47),
#             (   'SEAFOOD', 48),
#             (   'SEAFOOD', 49),
#             (   'SEAFOOD', 50),
#             (   'SEAFOOD', 51),
#             (   'SEAFOOD', 52),
#             (   'SEAFOOD', 53),
#             (   'SEAFOOD', 54)],
#            names=['family', 'store_nbr'], length=1782)

# %%
# inner layers 
retail.groupby(['family','store_nbr'])[['sales']].sum().loc[('AUTOMOTIVE',24),:]
# Out:
# sales    2234.0
# Name: (AUTOMOTIVE, 24), dtype: float64

# %%
retail.groupby(['family','store_nbr'])[['sales']].sum().loc[('AUTOMOTIVE','24'):('BEAUTY','24'),:]
# Out:
#                        sales
# family     store_nbr
# AUTOMOTIVE 24         2234.0
#            25         1745.0
#            26         2755.0
#            27         4085.0
#            28         4855.0
# ...                      ...
# BEAUTY     20         3536.0
#            21         2741.0
#            22          905.0
#            23         1220.0
#            24         3859.0
#
# [109 rows x 1 columns]

# %%
retail.groupby(['family','store_nbr'])[['sales']].sum().loc[('AUTOMOTIVE','24'):('AUTOMOTIVE','27'),:]
# Out:
#                        sales
# family     store_nbr
# AUTOMOTIVE 24         2234.0
#            25         1745.0
#            26         2755.0
#            27         4085.0

# %%
retail.groupby(['family','store_nbr'])[['sales']].sum().iloc[:4] # positional index
# Out:
#                        sales
# family     store_nbr
# AUTOMOTIVE 1          2524.0
#            2          3918.0
#            3          6790.0
#            4          2565.0

# %%
# multilevel column index 
retail.groupby(['family','store_nbr']).agg({"sales":['sum','mean']})
# Out:
#                              sales
#                                sum       mean
# family     store_nbr
# AUTOMOTIVE 1           2524.000000   4.263514
#            2           3918.000000   6.618243
#            3           6790.000000  11.469595
#            4           2565.000000   4.332770
#            5           3667.000000   6.194257
# ...                            ...        ...
# SEAFOOD    50         12773.966999  21.577647
#            51         34250.948976  57.856333
#            52          1219.475999   2.059926
#            53          3745.180001   6.326318
#            54          1082.000000   1.827703
#
# [1782 rows x 2 columns]

# %%
retail.groupby(['family','store_nbr']).agg({"sales":['sum','mean']}).iloc[0,0]
# Out:
# np.float64(2524.0)

# %%
retail.groupby(['family','store_nbr']).agg({"sales":['sum','mean']}).iloc[0,1]
# Out:
# np.float64(4.263513513513513)

# %%
retail.groupby(['family','store_nbr']).agg({"sales":['sum','mean']}).iloc[0,:]
# Out:
# sales  sum     2524.000000
#        mean       4.263514
# Name: (AUTOMOTIVE, 1), dtype: float64

# %%
retail.groupby(['family','store_nbr']).agg({"sales":['sum','mean']}).loc["SEAFOOD",("sales","sum")]
# Out:
# store_nbr
# 1     15898.003002
# 2     21453.224996
# 3     60799.703097
# 4     19222.407985
# 5      6751.715996
# 6     27767.546987
# 7     32790.004997
# 8     30746.884018
# 9     10363.489010
# 10     1865.000000
# 11     6017.000000
# 12     2743.000000
# 13     1517.000000
# 14     3099.000000
# 15     3235.000000
# 16      930.000000
# 17     8133.462000
# 18     5579.008001
# 19     2998.000000
# 20     8251.176989
# 21     3389.000000
# 22     1274.000000
# 23     8249.763009
# 24    19709.906009
# 25     3400.083000
# 26     1882.401000
# 27    13096.517999
# 28     4061.947000
# 29     4093.000000
# 30     2656.000000
# 31     3420.000000
# 32     1151.000000
# 33      907.000000
# 34     2311.000000
# 35      342.000000
# 36      858.000000
# 37    10072.682001
# 38    10552.260009
# 39     7701.136999
# 40     2544.000000
# 41     4524.587999
# 42    11396.924998
# 43      609.000000
# 44    68004.214969
# 45    60529.397995
# 46    32504.479029
# 47    52595.424000
# ...

# %% [markdown]
# ### modify multi - index DataFrames
# - reset the index
# - swap the index level
# - drop an index level

# %%
agg_sales = retail.groupby(['family','store_nbr']).agg({"sales":['sum','mean']})
agg_sales.head()
# Out:
#                        sales
#                          sum       mean
# family     store_nbr
# AUTOMOTIVE 1          2524.0   4.263514
#            2          3918.0   6.618243
#            3          6790.0  11.469595
#            4          2565.0   4.332770
#            5          3667.0   6.194257

# %%
agg_sales.droplevel(0,axis=1)
# Out:
#                                sum       mean
# family     store_nbr
# AUTOMOTIVE 1           2524.000000   4.263514
#            2           3918.000000   6.618243
#            3           6790.000000  11.469595
#            4           2565.000000   4.332770
#            5           3667.000000   6.194257
# ...                            ...        ...
# SEAFOOD    50         12773.966999  21.577647
#            51         34250.948976  57.856333
#            52          1219.475999   2.059926
#            53          3745.180001   6.326318
#            54          1082.000000   1.827703
#
# [1782 rows x 2 columns]

# %%
agg_sales.droplevel(0,axis=1).loc[:,"mean"]
# Out:
# family      store_nbr
# AUTOMOTIVE  1             4.263514
#             2             6.618243
#             3            11.469595
#             4             4.332770
#             5             6.194257
#                            ...
# SEAFOOD     50           21.577647
#             51           57.856333
#             52            2.059926
#             53            6.326318
#             54            1.827703
# Name: mean, Length: 1782, dtype: float64

# %%
agg_sales = agg_sales.droplevel(0,axis=1)

# %%
agg_sales.swaplevel()
# Out:
#                                sum       mean
# store_nbr family
# 1         AUTOMOTIVE   2524.000000   4.263514
# 2         AUTOMOTIVE   3918.000000   6.618243
# 3         AUTOMOTIVE   6790.000000  11.469595
# 4         AUTOMOTIVE   2565.000000   4.332770
# 5         AUTOMOTIVE   3667.000000   6.194257
# ...                            ...        ...
# 50        SEAFOOD     12773.966999  21.577647
# 51        SEAFOOD     34250.948976  57.856333
# 52        SEAFOOD      1219.475999   2.059926
# 53        SEAFOOD      3745.180001   6.326318
# 54        SEAFOOD      1082.000000   1.827703
#
# [1782 rows x 2 columns]

# %%
agg_sales.swaplevel().loc[1]
# Out:
#                                      sum         mean
# family
# AUTOMOTIVE                  2.524000e+03     4.263514
# BABY CARE                   0.000000e+00     0.000000
# BEAUTY                      1.776000e+03     3.000000
# BEVERAGES                   1.238601e+06  2092.231419
# BOOKS                       2.110000e+02     0.356419
# BREAD/BAKERY                2.239978e+05   378.374639
# CELEBRATION                 9.072000e+03    15.324324
# CLEANING                    3.906000e+05   659.797297
# DAIRY                       4.309830e+05   728.011824
# DELI                        7.653825e+04   129.287576
# EGGS                        8.050300e+04   135.984797
# FROZEN FOODS                7.374212e+04   124.564387
# GROCERY I                   1.512670e+06  2555.185811
# GROCERY II                  1.177300e+04    19.886824
# HARDWARE                    1.056000e+03     1.783784
# HOME AND KITCHEN I          1.232000e+04    20.810811
# ...

# %%
agg_sales.reset_index()
# Out:
#           family  store_nbr           sum       mean
# 0     AUTOMOTIVE          1   2524.000000   4.263514
# 1     AUTOMOTIVE          2   3918.000000   6.618243
# 2     AUTOMOTIVE          3   6790.000000  11.469595
# 3     AUTOMOTIVE          4   2565.000000   4.332770
# 4     AUTOMOTIVE          5   3667.000000   6.194257
# ...          ...        ...           ...        ...
# 1777     SEAFOOD         50  12773.966999  21.577647
# 1778     SEAFOOD         51  34250.948976  57.856333
# 1779     SEAFOOD         52   1219.475999   2.059926
# 1780     SEAFOOD         53   3745.180001   6.326318
# 1781     SEAFOOD         54   1082.000000   1.827703
#
# [1782 rows x 4 columns]

# %% [markdown]
# ### Exercise 3
# - Grab store , month 1
# - select column storing the mean transaction s
# - return to interger index and drop second column index that got created

# %%
transactions.head()
# Out:
#         date  store_nbr  transactions  month
# 0 2013-01-01         25           770      1
# 1 2013-01-02          1          2111      1
# 2 2013-01-02          2          2358      1
# 3 2013-01-02          3          3487      1
# 4 2013-01-02          4          1922      1

# %%
grouped = (
    transactions.groupby(['store_nbr','month'])
    .agg({'transactions':['sum','mean']})
    .sort_values(by=['month',('transactions','sum')],ascending=[True,False])
)

# %%
grouped.head()
# Out:
#                 transactions
#                          sum         mean
# store_nbr month
# 44        1           628438  4246.202703
# 47        1           568824  3843.405405
# 45        1           538370  3637.635135
# 46        1           522763  3532.182432
# 3         1           463260  3151.428571

# %%
grouped.iloc[4,:]
# Out:
# transactions  sum     463260.000000
#               mean      3151.428571
# Name: (3, 1), dtype: float64

# %%
grouped.loc[3,:].iloc[0,:]
# Out:
# transactions  sum     463260.000000
#               mean      3151.428571
# Name: 1, dtype: float64

# %%
grouped.loc[(3,1)]
# Out:
# transactions  sum     463260.000000
#               mean      3151.428571
# Name: (3, 1), dtype: float64

# %%
grouped.iloc[:,1]
# Out:
# store_nbr  month
# 44         1        4246.202703
# 47         1        3843.405405
# 45         1        3637.635135
# 46         1        3532.182432
# 3          1        3151.428571
#                        ...
# 32         12        718.058333
# 21         12       1402.133333
# 42         12       1279.016667
# 29         12       1277.116667
# 22         12        844.166667
# Name: (transactions, mean), Length: 641, dtype: float64

# %%
grouped.loc[:,('transactions','mean')]
# Out:
# store_nbr  month
# 44         1        4246.202703
# 47         1        3843.405405
# 45         1        3637.635135
# 46         1        3532.182432
# 3          1        3151.428571
#                        ...
# 32         12        718.058333
# 21         12       1402.133333
# 42         12       1279.016667
# 29         12       1277.116667
# 22         12        844.166667
# Name: (transactions, mean), Length: 641, dtype: float64

# %%
grouped.iloc[:,[1]] # dataframe
# Out:
#                         mean
# store_nbr month
# 44        1      4246.202703
# 47        1      3843.405405
# 45        1      3637.635135
# 46        1      3532.182432
# 3         1      3151.428571
# ...                      ...
# 32        12      718.058333
# 21        12     1402.133333
# 42        12     1279.016667
# 29        12     1277.116667
# 22        12      844.166667
#
# [641 rows x 1 columns]

# %%
grouped = grouped.droplevel(0,axis=1)
grouped.head()
# Out:
#                     sum         mean
# store_nbr month
# 44        1      628438  4246.202703
# 47        1      568824  3843.405405
# 45        1      538370  3637.635135
# 46        1      522763  3532.182432
# 3         1      463260  3151.428571

# %%
grouped.loc[:,'mean']
# Out:
# store_nbr  month
# 44         1        4246.202703
# 47         1        3843.405405
# 45         1        3637.635135
# 46         1        3532.182432
# 3          1        3151.428571
#                        ...
# 32         12        718.058333
# 21         12       1402.133333
# 42         12       1279.016667
# 29         12       1277.116667
# 22         12        844.166667
# Name: mean, Length: 641, dtype: float64

# %%
grouped.head()
# Out:
#                     sum         mean
# store_nbr month
# 44        1      628438  4246.202703
# 47        1      568824  3843.405405
# 45        1      538370  3637.635135
# 46        1      522763  3532.182432
# 3         1      463260  3151.428571

# %%
grouped.reset_index()
# Out:
#      store_nbr  month     sum         mean
# 0           44      1  628438  4246.202703
# 1           47      1  568824  3843.405405
# 2           45      1  538370  3637.635135
# 3           46      1  522763  3532.182432
# 4            3      1  463260  3151.428571
# ..         ...    ...     ...          ...
# 636         32     12   86167   718.058333
# 637         21     12   84128  1402.133333
# 638         42     12   76741  1279.016667
# 639         29     12   76627  1277.116667
# 640         22     12   50650   844.166667
#
# [641 rows x 4 columns]
