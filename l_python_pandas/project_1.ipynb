# %%
import pandas as pd 
import numpy as np

# %%
transactions = pd.read_csv("/Users/arunadas/Desktop/dev/python/project_data/project_transactions.csv")
#../project_data/project_transactions.csv")

# %%
transactions.head()
# Out:
#    household_key    BASKET_ID  DAY  PRODUCT_ID  QUANTITY  SALES_VALUE  \
# 0           1364  26984896261    1      842930         1         2.19
# 1           1364  26984896261    1      897044         1         2.99
# 2           1364  26984896261    1      920955         1         3.09
# 3           1364  26984896261    1      937406         1         2.50
# 4           1364  26984896261    1      981760         1         0.60
#
#    STORE_ID  RETAIL_DISC  WEEK_NO  COUPON_DISC  COUPON_MATCH_DISC
# 0     31742         0.00        1          0.0                0.0
# 1     31742        -0.40        1          0.0                0.0
# 2     31742         0.00        1          0.0                0.0
# 3     31742        -0.99        1          0.0                0.0
# 4     31742        -0.79        1          0.0                0.0

# %%
transactions.info(memory_usage="deep")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2146311 entries, 0 to 2146310
# Data columns (total 11 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   household_key      int64
#  1   BASKET_ID          int64
#  2   DAY                int64
#  3   PRODUCT_ID         int64
#  4   QUANTITY           int64
#  5   SALES_VALUE        float64
#  6   STORE_ID           int64
#  7   RETAIL_DISC        float64
#  8   WEEK_NO            int64
#  9   COUPON_DISC        float64
#  10  COUPON_MATCH_DISC  float64
# dtypes: float64(4), int64(7)
# memory usage: 180.1 MB

# %%
transactions.describe()
# Out:
#        household_key     BASKET_ID           DAY    PRODUCT_ID      QUANTITY  \
# count   2.146311e+06  2.146311e+06  2.146311e+06  2.146311e+06  2.146311e+06
# mean    1.056232e+03  3.404897e+10  3.895059e+02  2.884715e+06  1.009703e+02
# std     6.050059e+02  4.723748e+09  1.900530e+02  3.831949e+06  1.152364e+03
# min     1.000000e+00  2.698490e+10  1.000000e+00  2.567100e+04  0.000000e+00
# 25%     5.480000e+02  3.040798e+10  2.290000e+02  9.172310e+05  1.000000e+00
# 50%     1.042000e+03  3.281176e+10  3.920000e+02  1.027960e+06  1.000000e+00
# 75%     1.581000e+03  4.012804e+10  5.550000e+02  1.132771e+06  1.000000e+00
# max     2.099000e+03  4.230536e+10  7.110000e+02  1.831630e+07  8.963800e+04
#
#         SALES_VALUE      STORE_ID   RETAIL_DISC       WEEK_NO   COUPON_DISC  \
# count  2.146311e+06  2.146311e+06  2.146311e+06  2.146311e+06  2.146311e+06
# mean   3.105908e+00  3.267939e+03 -5.333568e-01  5.632742e+01 -1.579855e-02
# ...

# %%
transactions['COUPON_MATCH_DISC'].max()
# Out:
# np.float16(0.0)

# %%
transactions['household_key'].min()
# Out:
# np.int64(1)

# %%
transactions = transactions.astype(
    {
        'household_key':'int8',
        'DAY':'int16',
        'PRODUCT_ID':'int16',
        'QUANTITY':'int32',
        'SALES_VALUE':'float32',
        'STORE_ID':'int32',
        'RETAIL_DISC':'float32',
        'COUPON_DISC':'float32',
        'COUPON_MATCH_DISC':'float32',
        'WEEK_NO':'int8'
    }
)

# %%
transactions.info(memory_usage="deep")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2146311 entries, 0 to 2146310
# Data columns (total 11 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   household_key      int8
#  1   BASKET_ID          int64
#  2   DAY                int16
#  3   PRODUCT_ID         int16
#  4   QUANTITY           int32
#  5   SALES_VALUE        float32
#  6   STORE_ID           int32
#  7   RETAIL_DISC        float32
#  8   WEEK_NO            int8
#  9   COUPON_DISC        float32
#  10  COUPON_MATCH_DISC  float32
# dtypes: float32(4), int16(2), int32(2), int64(1), int8(2)
# memory usage: 77.8 MB

# %%
print(f"shape : {transactions.shape}")
print(f"size : {transactions.size}")
print(f"index : {transactions.index}")
print(f"columns : {transactions.columns}")
print(f"dtypes : {transactions.dtypes}")
# Out:
# shape : (2146311, 11)
# size : 23609421
# index : RangeIndex(start=0, stop=2146311, step=1)
# columns : Index(['household_key', 'BASKET_ID', 'DAY', 'PRODUCT_ID', 'QUANTITY',
#        'SALES_VALUE', 'STORE_ID', 'RETAIL_DISC', 'WEEK_NO', 'COUPON_DISC',
#        'COUPON_MATCH_DISC'],
#       dtype='object')
# dtypes : household_key           int8
# BASKET_ID              int64
# DAY                     int8
# PRODUCT_ID             int16
# QUANTITY                int8
# SALES_VALUE          float32
# STORE_ID                int8
# RETAIL_DISC          float32
# WEEK_NO                int64
# COUPON_DISC          float32
# COUPON_MATCH_DISC    float32
# dtype: object

# %%
transactions.tail()
# Out:
#          household_key    BASKET_ID  DAY  PRODUCT_ID  QUANTITY  SALES_VALUE  \
# 2146306             62  42305362535  -57       26594         1     0.990234
# 2146307             62  42305362535  -57      -16970         1     8.890625
# 2146308             62  42305362535  -57        2377         1     6.988281
# 2146309             62  42305362535  -57      -23172         1     4.500000
# 2146310             62  42305362535  -57       30488         1     6.988281
#
#          STORE_ID  RETAIL_DISC  WEEK_NO  COUPON_DISC  COUPON_MATCH_DISC
# 2146306      -100      0.00000      102          0.0                0.0
# 2146307      -100      0.00000      102          0.0                0.0
# 2146308      -100      0.00000      102          0.0                0.0
# 2146309      -100     -0.48999      102          0.0                0.0
# 2146310      -100      0.00000      102          0.0                0.0

# %%
transactions.head()
# Out:
#    household_key    BASKET_ID  DAY  PRODUCT_ID  QUANTITY  SALES_VALUE  \
# 0             84  26984896261    1       -9038         1     2.189453
# 1             84  26984896261    1      -20460         1     2.990234
# 2             84  26984896261    1        3451         1     3.089844
# 3             84  26984896261    1       19902         1     2.500000
# 4             84  26984896261    1       -1280         1     0.600098
#
#    STORE_ID  RETAIL_DISC  WEEK_NO  COUPON_DISC  COUPON_MATCH_DISC
# 0        -2     0.000000        1          0.0                0.0
# 1        -2    -0.399902        1          0.0                0.0
# 2        -2     0.000000        1          0.0                0.0
# 3        -2    -0.990234        1          0.0                0.0
# 4        -2    -0.790039        1          0.0                0.0

# %%
transactions.sample()
# Out:
#          household_key    BASKET_ID  DAY  PRODUCT_ID  QUANTITY  SALES_VALUE  \
# 2143837            -64  42289577197  -57      -26938         1          1.0
#
#          STORE_ID  RETAIL_DISC  WEEK_NO  COUPON_DISC  COUPON_MATCH_DISC
# 2143837      -111          0.0      102          0.0                0.0

# %%
transactions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2146311 entries, 0 to 2146310
# Data columns (total 11 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   household_key      int8
#  1   BASKET_ID          int64
#  2   DAY                int8
#  3   PRODUCT_ID         int16
#  4   QUANTITY           int8
#  5   SALES_VALUE        float32
#  6   STORE_ID           int8
#  7   RETAIL_DISC        float32
#  8   WEEK_NO            int64
#  9   COUPON_DISC        float32
#  10  COUPON_MATCH_DISC  float32
# dtypes: float32(4), int16(1), int64(2), int8(4)
# memory usage: 77.8 MB

# %%
transactions.describe(include='all')
# Out:
#        household_key     BASKET_ID           DAY    PRODUCT_ID      QUANTITY  \
# count   2.146311e+06  2.146311e+06  2.146311e+06  2.146311e+06  2.146311e+06
# mean    9.036412e-01  3.404897e+10 -1.978396e+00 -1.049076e+02  1.286559e+00
# std     7.348088e+01  4.723748e+09  7.853211e+01  1.865645e+04  7.102197e+00
# min    -1.280000e+02  2.698490e+10 -1.280000e+02 -3.276800e+04 -1.280000e+02
# 25%    -6.000000e+01  3.040798e+10 -7.500000e+01 -1.670200e+04  1.000000e+00
# 50%     1.000000e+00  3.281176e+10 -2.000000e+00 -2.920000e+02  1.000000e+00
# 75%     6.300000e+01  4.012804e+10  7.000000e+01  1.556300e+04  1.000000e+00
# max     1.270000e+02  4.230536e+10  1.270000e+02  3.276700e+04  1.270000e+02
#
#         SALES_VALUE      STORE_ID   RETAIL_DISC       WEEK_NO   COUPON_DISC  \
# count  2.146311e+06  2.146311e+06  2.146311e+06  2.146311e+06  2.146311e+06
# mean   3.105861e+00  1.512709e+01 -5.333593e-01  5.632742e+01 -1.579832e-02
# ...

# %%
transactions.info(show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2146311 entries, 0 to 2146310
# Data columns (total 11 columns):
#  #   Column             Non-Null Count    Dtype
# ---  ------             --------------    -----
#  0   household_key      2146311 non-null  int8
#  1   BASKET_ID          2146311 non-null  int64
#  2   DAY                2146311 non-null  int8
#  3   PRODUCT_ID         2146311 non-null  int16
#  4   QUANTITY           2146311 non-null  int8
#  5   SALES_VALUE        2146311 non-null  float32
#  6   STORE_ID           2146311 non-null  int8
#  7   RETAIL_DISC        2146311 non-null  float32
#  8   WEEK_NO            2146311 non-null  int64
#  9   COUPON_DISC        2146311 non-null  float32
#  10  COUPON_MATCH_DISC  2146311 non-null  float32
# dtypes: float32(4), int16(1), int64(2), int8(4)
# memory usage: 77.8 MB

# %%
transactions.isna().sum()
# Out:
# household_key        0
# BASKET_ID            0
# DAY                  0
# PRODUCT_ID           0
# QUANTITY             0
# SALES_VALUE          0
# STORE_ID             0
# RETAIL_DISC          0
# WEEK_NO              0
# COUPON_DISC          0
# COUPON_MATCH_DISC    0
# dtype: int64

# %%
# unique household and product id 
transactions["household_key"].nunique()
# Out:
# 256

# %%
transactions["PRODUCT_ID"].nunique()
# Out:
# 47950

# %%
# create total_discount 
transactions["total_discount"] = transactions["RETAIL_DISC"] + transactions["COUPON_DISC"]

# %%
transactions.head()
# Out:
#    household_key    BASKET_ID  DAY  PRODUCT_ID  QUANTITY  SALES_VALUE  \
# 0           1364  26984896261    1      842930         1         2.19
# 1           1364  26984896261    1      897044         1         2.99
# 2           1364  26984896261    1      920955         1         3.09
# 3           1364  26984896261    1      937406         1         2.50
# 4           1364  26984896261    1      981760         1         0.60
#
#    STORE_ID  RETAIL_DISC  WEEK_NO  COUPON_DISC  COUPON_MATCH_DISC  \
# 0     31742         0.00        1          0.0                0.0
# 1     31742        -0.40        1          0.0                0.0
# 2     31742         0.00        1          0.0                0.0
# 3     31742        -0.99        1          0.0                0.0
# 4     31742        -0.79        1          0.0                0.0
#
#    total_discount
# 0            0.00
# 1           -0.40
# 2            0.00
# 3           -0.99
# 4           -0.79

# %%
transactions["percentage_discount"] = transactions["total_discount"]/transactions["SALES_VALUE"].abs()

# %%
transactions.head()
# Out:
#    household_key    BASKET_ID  DAY  PRODUCT_ID  QUANTITY  SALES_VALUE  \
# 0           1364  26984896261    1      842930         1         2.19
# 1           1364  26984896261    1      897044         1         2.99
# 2           1364  26984896261    1      920955         1         3.09
# 3           1364  26984896261    1      937406         1         2.50
# 4           1364  26984896261    1      981760         1         0.60
#
#    STORE_ID  RETAIL_DISC  WEEK_NO  COUPON_DISC  COUPON_MATCH_DISC  \
# 0     31742         0.00        1          0.0                0.0
# 1     31742        -0.40        1          0.0                0.0
# 2     31742         0.00        1          0.0                0.0
# 3     31742        -0.99        1          0.0                0.0
# 4     31742        -0.79        1          0.0                0.0
#
#    total_discount  percentage_discount
# 0            0.00             0.000000
# 1           -0.40            -0.133779
# ...

# %%
conditions = [
    (transactions["percentage_discount"]>1),
    (transactions["percentage_discount"]<0)
]

choices = [1,0]

transactions["percentage_discount"] = np.select(conditions, choices)

# %%
transactions.head()
# Out:
#    household_key    BASKET_ID  DAY  PRODUCT_ID  QUANTITY  SALES_VALUE  \
# 0           1364  26984896261    1      842930         1         2.19
# 1           1364  26984896261    1      897044         1         2.99
# 2           1364  26984896261    1      920955         1         3.09
# 3           1364  26984896261    1      937406         1         2.50
# 4           1364  26984896261    1      981760         1         0.60
#
#    STORE_ID  RETAIL_DISC  WEEK_NO  COUPON_DISC  COUPON_MATCH_DISC  \
# 0     31742         0.00        1          0.0                0.0
# 1     31742        -0.40        1          0.0                0.0
# 2     31742         0.00        1          0.0                0.0
# 3     31742        -0.99        1          0.0                0.0
# 4     31742        -0.79        1          0.0                0.0
#
#    total_discount  percentage_discount
# 0            0.00                    0
# 1           -0.40                    0
# ...

# %%
transactions.drop(
    [
        'RETAIL_DISC',
        'COUPON_DISC',
        'COUPON_MATCH_DISC'
    ],
    axis=1,
    inplace=True
)

# %%
transactions.head()
# Out:
#    household_key    BASKET_ID  DAY  PRODUCT_ID  QUANTITY  SALES_VALUE  \
# 0           1364  26984896261    1      842930         1         2.19
# 1           1364  26984896261    1      897044         1         2.99
# 2           1364  26984896261    1      920955         1         3.09
# 3           1364  26984896261    1      937406         1         2.50
# 4           1364  26984896261    1      981760         1         0.60
#
#    STORE_ID  WEEK_NO  total_discount  percentage_discount
# 0     31742        1            0.00                    0
# 1     31742        1           -0.40                    0
# 2     31742        1            0.00                    0
# 3     31742        1           -0.99                    0
# 4     31742        1           -0.79                    0

# %%
transactions.head()
# Out:
#    household_key    BASKET_ID  DAY  PRODUCT_ID  QUANTITY  SALES_VALUE  \
# 0           1364  26984896261    1      842930         1         2.19
# 1           1364  26984896261    1      897044         1         2.99
# 2           1364  26984896261    1      920955         1         3.09
# 3           1364  26984896261    1      937406         1         2.50
# 4           1364  26984896261    1      981760         1         0.60
#
#    STORE_ID  RETAIL_DISC  WEEK_NO  COUPON_DISC  COUPON_MATCH_DISC
# 0     31742         0.00        1          0.0                0.0
# 1     31742        -0.40        1          0.0                0.0
# 2     31742         0.00        1          0.0                0.0
# 3     31742        -0.99        1          0.0                0.0
# 4     31742        -0.79        1          0.0                0.0

# %%
### transaction 
transactions = (
    transactions
    .assign(total_discount = transactions["RETAIL_DISC"] + transactions["COUPON_DISC"],
      percentage_discount = (lambda x: (x["total_discount"]/x["SALES_VALUE"]).abs()))
    .drop(['RETAIL_DISC','COUPON_DISC','COUPON_MATCH_DISC'],axis=1)      
            
)

# %%
transactions.head()
# Out:
#    household_key    BASKET_ID  DAY  PRODUCT_ID  QUANTITY  SALES_VALUE  \
# 0           1364  26984896261    1      842930         1         2.19
# 1           1364  26984896261    1      897044         1         2.99
# 2           1364  26984896261    1      920955         1         3.09
# 3           1364  26984896261    1      937406         1         2.50
# 4           1364  26984896261    1      981760         1         0.60
#
#    STORE_ID  WEEK_NO  total_discount  percentage_discount
# 0     31742        1            0.00             0.000000
# 1     31742        1           -0.40             0.133779
# 2     31742        1            0.00             0.000000
# 3     31742        1           -0.99             0.396000
# 4     31742        1           -0.79             1.316667

# %%
transactions["percentage_discount"] = (transactions["percentage_discount"]
                                       .where(transactions["percentage_discount"]<1,1.0)
                                       .where(transactions["percentage_discount"]>0,0) #false
                                      )

# %%
transactions.head()
# Out:
#    household_key    BASKET_ID  DAY  PRODUCT_ID  QUANTITY  SALES_VALUE  \
# 0           1364  26984896261    1      842930         1         2.19
# 1           1364  26984896261    1      897044         1         2.99
# 2           1364  26984896261    1      920955         1         3.09
# 3           1364  26984896261    1      937406         1         2.50
# 4           1364  26984896261    1      981760         1         0.60
#
#    STORE_ID  WEEK_NO  total_discount  percentage_discount
# 0     31742        1            0.00             0.000000
# 1     31742        1           -0.40             0.133779
# 2     31742        1            0.00             0.000000
# 3     31742        1           -0.99             0.396000
# 4     31742        1           -0.79             1.000000

# %% [markdown]
# ### Overall Statistics
# calculate
# - total sales (sum of sales_values)
# - total discount
# - % discount sum of total_discount/ sum of sales value
# - total qty sold
# - max qty sold in a single row . Inspect the row. Does this have a high discount percentage?
# - Total sales value / basket ( sum of sales value / nunique basket_id)
# - total sales value per household ( sum of sales value / nunique household_key)

# %%
# total sales 
transactions["SALES_VALUE"].sum().round(2) # 6.6 million
# Out:
# np.float64(6666243.5)

# %%
# total discount 
transactions["total_discount"].sum().round(2)
# Out:
# np.float64(-1178658.08)

# %%
# % discount sum of total_discount/ sum of sales value
(transactions["total_discount"].sum()/transactions["SALES_VALUE"].sum()  )* 100
# Out:
# np.float64(-17.68099350106248)

# %%
transactions["percentage_discount"].mean()
# Out:
# np.float64(0.2073244407398103)

# %%
# total qty sold
transactions["QUANTITY"].sum()
# Out:
# np.int64(216713611)

# %%
transactions.loc[transactions["QUANTITY"]== transactions["QUANTITY"].max()]
# Out:
#          household_key    BASKET_ID  DAY  PRODUCT_ID  QUANTITY  SALES_VALUE  \
# 1442095            630  34749153595  503     6534178     89638        250.0
#
#          STORE_ID  WEEK_NO  total_discount  percentage_discount
# 1442095       384       73          -13.45               0.0538

# %%
transactions.query("QUANTITY == QUANTITY.max()")
# Out:
#          household_key    BASKET_ID  DAY  PRODUCT_ID  QUANTITY  SALES_VALUE  \
# 1442095            630  34749153595  503     6534178     89638        250.0
#
#          STORE_ID  WEEK_NO  total_discount  percentage_discount
# 1442095       384       73          -13.45               0.0538

# %%
transactions.loc[transactions["QUANTITY"].argmax()]
# Out:
# household_key          6.300000e+02
# BASKET_ID              3.474915e+10
# DAY                    5.030000e+02
# PRODUCT_ID             6.534178e+06
# QUANTITY               8.963800e+04
# SALES_VALUE            2.500000e+02
# STORE_ID               3.840000e+02
# WEEK_NO                7.300000e+01
# total_discount        -1.345000e+01
# percentage_discount    5.380000e-02
# Name: 1442095, dtype: float64

# %%
transactions["BASKET_ID"].nunique()
# Out:
# 232939

# %%
(transactions["SALES_VALUE"].sum()/transactions["BASKET_ID"].nunique()).round(2)
# Out:
# np.float64(28.62)

# %%
(transactions["SALES_VALUE"].sum()/transactions["household_key"].nunique()).round(2)
# Out:
# np.float64(3175.91)

# %% [markdown]
# ### Household Analysis
# - plot the distribution of total sales value purchased at the household level
# - what are the top 10 households by quantity purchased ?
# - what were the top 10 households by sales value?
# - plot the total sales value for our top 10 households by value , ordered from hihest to lowest

# %%
## By store
(transactions
 .groupby(['store_nbr'], as_index=False)
 .agg(st_target_mean=('target_pct','mean'),
      st_bonus=('bonus_payable','sum'))
).sort_values('st_bonus', ascending=False).head()

# %%
#
household_level = (transactions
 .groupby(["household_key"])
 .agg(total_sales=('SALES_VALUE','sum'))
)

# %%
household_level.head()
# Out:
#    household_key  total_sales
# 0              1      4330.16
# 1              2      1954.34
# 2              3      2653.21
# 3              4      1200.11
# 4              5       779.06

# %%
(transactions
 .groupby(["household_key"])
 .agg({'SALES_VALUE':'sum'})
 )
# Out:
#                SALES_VALUE
# household_key
# 1                  4330.16
# 2                  1954.34
# 3                  2653.21
# 4                  1200.11
# 5                   779.06
# ...                    ...
# 2095               3790.49
# 2096               1301.65
# 2097               8823.83
# 2098                682.46
# 2099                691.30
#
# [2099 rows x 1 columns]

# %%
household_level.loc[:,"total_sales"].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
(transactions
 .groupby(["household_key"])
 .agg({'SALES_VALUE':'sum'})
 ).plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
 (transactions
 .groupby(["household_key"], as_index=False)
 .agg(max_qty=('QUANTITY','sum'))
).sort_values('max_qty', ascending = False).head(10)
# Out:
#       household_key  max_qty
# 1022           1023  4479917
# 754             755  3141769
# 1608           1609  2146715
# 12               13  1863829
# 1429           1430  1741892
# 1526           1527  1734632
# 1761           1762  1669880
# 706             707  1640193
# 1028           1029  1496204
# 1313           1314  1492863

# %%
 (transactions
 .groupby(["household_key"], as_index=False)
 .agg(sales_value=('SALES_VALUE','sum'))
).sort_values('sales_value', ascending = False).iloc[:10]
# Out:
#       household_key  sales_value
# 1022           1023     38319.79
# 1608           1609     27859.68
# 1452           1453     21661.29
# 1429           1430     20352.99
# 717             718     19299.86
# 706             707     19194.42
# 1652           1653     19153.75
# 1110           1111     18894.72
# 981             982     18790.34
# 399             400     18494.14

# %%
 (transactions
 .groupby(["household_key"])
 .agg({'SALES_VALUE':'sum'})
.sort_values('SALES_VALUE', ascending = False)
.iloc[:10])
# Out:
#                SALES_VALUE
# household_key
# 1023              38319.79
# 1609              27859.68
# 1453              21661.29
# 1430              20352.99
# 718               19299.86
# 707               19194.42
# 1653              19153.75
# 1111              18894.72
# 982               18790.34
# 400               18494.14

# %%
 top10 = (transactions
 .groupby(["household_key"])
 .agg(sales_value=('SALES_VALUE','sum'),
     sales_qty=('QUANTITY','sum'))
).sort_values('sales_value', ascending = False).head(10)

# %%
top10.head()
# Out:
#                sales_value  sales_qty
# household_key
# 1023              38319.79    4479917
# 1609              27859.68    2146715
# 1453              21661.29      95743
# 1430              20352.99    1741892
# 718               19299.86     869732

# %%
top10['sales_value'].plot.bar();

# %% [markdown]
# ### Product Analysis
# - which product has the most sales by sales_value ? Plot a horizontal bar chart
# - Did the top 10 selling items have a higher than average discount rate?
# - What was the most common PRODUCT_ID among rows with the households in out top 10 households by sale value?
# - Look up top 10 names of product by sales in product.csv dataset
# - Look up product name of item that had the highest quantity sold in a single row

# %%
transactions.head()
# Out:
#    household_key    BASKET_ID  DAY  PRODUCT_ID  QUANTITY  SALES_VALUE  \
# 0           1364  26984896261    1      842930         1         2.19
# 1           1364  26984896261    1      897044         1         2.99
# 2           1364  26984896261    1      920955         1         3.09
# 3           1364  26984896261    1      937406         1         2.50
# 4           1364  26984896261    1      981760         1         0.60
#
#    STORE_ID  WEEK_NO  total_discount  percentage_discount
# 0     31742        1            0.00             0.000000
# 1     31742        1           -0.40             0.133779
# 2     31742        1            0.00             0.000000
# 3     31742        1           -0.99             0.396000
# 4     31742        1           -0.79             1.000000

# %%
top10_prod = (transactions
 .groupby('PRODUCT_ID')
 .agg({'SALES_VALUE':'sum'})
 .sort_values('SALES_VALUE', ascending = False)
).iloc[:10]

top10_prod.head()
# Out:
#             SALES_VALUE
# PRODUCT_ID
# 6534178       420154.13
# 6533889        42339.31
# 1029743        33894.75
# 1082185        24149.79
# 6533765        23831.14

# %%
top10_prod["SALES_VALUE"].sort_values().plot.barh()
# Out:
# <Axes: ylabel='PRODUCT_ID'>

# %%
#Did the top 10 selling items have a higher than average discount rate?
((transactions
 .query("PRODUCT_ID in @top10_prod.index")
 .loc[:,"total_discount"]
 .sum())
 /(transactions
 .query("PRODUCT_ID in @top10_prod.index")
 .loc[:,"SALES_VALUE"]
 .sum())
)
# Out:
# np.float64(-0.10331267387397927)

# %%
transactions['percentage_discount'].mean()
# Out:
# np.float64(0.2073244407398103)

# %%
#Did the top 10 selling items have a higher than average discount rate?
transactions.loc[transactions['PRODUCT_ID'].isin(top10_prd.index)]
# Out:
#          household_key    BASKET_ID  DAY  PRODUCT_ID  QUANTITY  SALES_VALUE  \
# 16                  98  26984951769    1     1082185         1         0.39
# 29                1172  26985025264    1     1106523         1         1.50
# 31                1172  26985025264    1     5569230         1         2.33
# 69                1060  26985040735    1     1082185         1         0.84
# 80                1060  26985040735    1     5569230         1         2.33
# ...                ...          ...  ...         ...       ...          ...
# 2146231           1098  42289918722  711     1082185         1         0.51
# 2146248            303  42289918892  711      995242         1         1.94
# 2146255            303  42289918892  711     1082185         1         1.10
# 2146278            761  42289921056  711     1029743         1         2.89
# 2146281            761  42289921056  711     1106523         2         5.78
#
# ...

# %%
#What was the most common PRODUCT_ID among rows with the households in out top 10 households by sale value?
top10_household = (transactions
 .groupby('household_key')
 .agg({'SALES_VALUE':'sum'})
 .sort_values('SALES_VALUE', ascending = False)
 .iloc[:10])

# %%
top10_households2 = (
    transactions.groupby("household_key")["SALES_VALUE"]
    .sum()
    .nlargest(10)  # Select top 10 households
)
top10_households2.head()
# Out:
# household_key
# 1023    38319.79
# 1609    27859.68
# 1453    21661.29
# 1430    20352.99
# 718     19299.86
# Name: SALES_VALUE, dtype: float64

# %%
top10_household.head()
# Out:
#                SALES_VALUE
# household_key
# 1023              38319.79
# 1609              27859.68
# 1453              21661.29
# 1430              20352.99
# 718               19299.86

# %%
top10_household_trans = transactions.loc[transactions['household_key'].isin(top10_household.index)]

top10_household_trans.head()
# Out:
#      household_key    BASKET_ID  DAY  PRODUCT_ID  QUANTITY  SALES_VALUE  \
# 118            718  26985360571    1      830503         1         2.99
# 119            718  26985360571    1      839605         1         2.50
# 120            718  26985360571    1      840664         1         0.55
# 121            718  26985360571    1      844685         2         1.98
# 122            718  26985360571    1      848015         2         1.20
#
#      STORE_ID  WEEK_NO  total_discount  percentage_discount
# 118       324        1           -2.00             0.668896
# 119       324        1           -0.99             0.396000
# 120       324        1            0.00             0.000000
# 121       324        1           -1.60             0.808081
# 122       324        1           -0.18             0.150000

# %%
(
    top10_household_trans['PRODUCT_ID']
    .value_counts()
    .idxmax()
)
# Out:
# np.int64(1082185)

# %%
products = pd.read_csv("/Users/arunadas/Desktop/dev/python/project_data/product.csv")
products.head()
# Out:
#    PRODUCT_ID  MANUFACTURER    DEPARTMENT     BRAND            COMMODITY_DESC  \
# 0       25671             2       GROCERY  National                  FRZN ICE
# 1       26081             2  MISC. TRANS.  National  NO COMMODITY DESCRIPTION
# 2       26093            69        PASTRY   Private                     BREAD
# 3       26190            69       GROCERY   Private      FRUIT - SHELF STABLE
# 4       26355            69       GROCERY   Private             COOKIES/CONES
#
#             SUB_COMMODITY_DESC CURR_SIZE_OF_PRODUCT
# 0          ICE - CRUSHED/CUBED                22 LB
# 1  NO SUBCOMMODITY DESCRIPTION
# 2         BREAD:ITALIAN/FRENCH
# 3                  APPLE SAUCE                50 OZ
# 4            SPECIALTY COOKIES                14 OZ

# %%
# Look up top 10 names of product by sales in product.csv dataset

(
    products.loc[products['PRODUCT_ID'].isin(top10_household_trans['PRODUCT_ID'])]
)['COMMODITY_DESC'].value_counts().iloc[:10]
# Out:
# COMMODITY_DESC
# CANDY - PACKAGED                395
# SOFT DRINKS                     361
# FRZN MEAT/MEAT DINNERS          302
# BAG SNACKS                      288
# FROZEN PIZZA                    257
# HISPANIC                        235
# CHEESE                          225
# BAKED BREAD/BUNS/ROLLS          211
# HAIR CARE PRODUCTS              205
# STATIONERY & SCHOOL SUPPLIES    205
# Name: count, dtype: int64

# %%
top_hh_products = (transactions
 .query("household_key in @top10.index")
 .loc[:,'PRODUCT_ID']
 .value_counts()
 .iloc[:10]
 .index
)

# %%
products.query("PRODUCT_ID in @top_hh_products")
# Out:
#        PRODUCT_ID  MANUFACTURER       DEPARTMENT     BRAND  \
# 10630      860776             2          PRODUCE  National
# 20973      951590           910          GROCERY  National
# 24250      981760            69          GROCERY   Private
# 29657     1029743            69          GROCERY   Private
# 35576     1082185             2          PRODUCE  National
# 38262     1106523            69          GROCERY   Private
# 40600     1127831          5937          PRODUCE  National
# 57181     6533889            69  MISC SALES TRAN   Private
# 57221     6534178            69        KIOSK-GAS   Private
# 68952     9677202            69          GROCERY   Private
#
#                 COMMODITY_DESC      SUB_COMMODITY_DESC CURR_SIZE_OF_PRODUCT
# 10630  VEGETABLES - ALL OTHERS               CUCUMBERS                36 CT
# 20973   BAKED BREAD/BUNS/ROLLS  MAINSTREAM WHITE BREAD                20 OZ
# 24250                     EGGS          EGGS - X-LARGE                 1 DZ
# ...

# %%
# Look up product name of item that had the highest quantity sold in a single row
top10_household_qty = (transactions
 .groupby('PRODUCT_ID')
 .agg({'QUANTITY':'sum'})
 .sort_values('QUANTITY', ascending = False)
 .iloc[:10])

top10_household_qty.head(1)
# Out:
#              QUANTITY
# PRODUCT_ID
# 6534178     180705254

# %%
products.loc[products['PRODUCT_ID']== 6534178]
# Out:
#        PRODUCT_ID  MANUFACTURER DEPARTMENT    BRAND     COMMODITY_DESC  \
# 57221     6534178            69  KIOSK-GAS  Private  COUPON/MISC ITEMS
#
#           SUB_COMMODITY_DESC CURR_SIZE_OF_PRODUCT
# 57221  GASOLINE-REG UNLEADED

# %%
products.query("PRODUCT_ID == 6534178")
# Out:
#        PRODUCT_ID  MANUFACTURER DEPARTMENT    BRAND     COMMODITY_DESC  \
# 57221     6534178            69  KIOSK-GAS  Private  COUPON/MISC ITEMS
#
#           SUB_COMMODITY_DESC CURR_SIZE_OF_PRODUCT
# 57221  GASOLINE-REG UNLEADED

# %%
# look up 10 products names for all customers (from first cell)
products.query("PRODUCT_ID in @top10_prod.index")
# Out:
#        PRODUCT_ID  MANUFACTURER       DEPARTMENT     BRAND  \
# 16863      916122          4314             MEAT  National
# 25754      995242            69          GROCERY   Private
# 29657     1029743            69          GROCERY   Private
# 35576     1082185             2          PRODUCE  National
# 38262     1106523            69          GROCERY   Private
# 53097     5569230          1208          GROCERY  National
# 57171     6533765            69        KIOSK-GAS   Private
# 57181     6533889            69  MISC SALES TRAN   Private
# 57216     6534166            69  MISC SALES TRAN   Private
# 57221     6534178            69        KIOSK-GAS   Private
#
#             COMMODITY_DESC              SUB_COMMODITY_DESC  \
# 16863              CHICKEN         CHICKEN BREAST BONELESS
# 25754  FLUID MILK PRODUCTS           FLUID MILK WHITE ONLY
# 29657  FLUID MILK PRODUCTS           FLUID MILK WHITE ONLY
# 35576       TROPICAL FRUIT                         BANANAS
# ...
