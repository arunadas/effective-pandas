# %%
from datetime import datetime

now = datetime.now()

now
# Out:
# datetime.datetime(2025, 3, 15, 22, 12, 56, 92439)

# %% [markdown]
# # astype
# - NA object , ignore = errors
# pd.to_datetime
# errors="coerce"
# infer_datetime_format=True
# # format = "%Y=%M-%D"

# %%
import pandas as pd 

retail = pd.read_csv("./retail/retail_2016_2017.csv")

retail.head()
# Out:
#         id        date  store_nbr      family  sales  onpromotion
# 0  1945944  2016-01-01          1  AUTOMOTIVE    0.0            0
# 1  1945945  2016-01-01          1   BABY CARE    0.0            0
# 2  1945946  2016-01-01          1      BEAUTY    0.0            0
# 3  1945947  2016-01-01          1   BEVERAGES    0.0            0
# 4  1945948  2016-01-01          1       BOOKS    0.0            0

# %%
retail.info(memory_usage="deep")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1054944 entries, 0 to 1054943
# Data columns (total 6 columns):
#  #   Column       Non-Null Count    Dtype
# ---  ------       --------------    -----
#  0   id           1054944 non-null  int64
#  1   date         1054944 non-null  object
#  2   store_nbr    1054944 non-null  int64
#  3   family       1054944 non-null  object
#  4   sales        1054944 non-null  float64
#  5   onpromotion  1054944 non-null  int64
# dtypes: float64(1), int64(3), object(2)
# memory usage: 167.8 MB

# %%
retail = retail.astype({"date":"datetime64[ns]"})
retail.head()
# Out:
#         id       date  store_nbr      family  sales  onpromotion
# 0  1945944 2016-01-01          1  AUTOMOTIVE    0.0            0
# 1  1945945 2016-01-01          1   BABY CARE    0.0            0
# 2  1945946 2016-01-01          1      BEAUTY    0.0            0
# 3  1945947 2016-01-01          1   BEVERAGES    0.0            0
# 4  1945948 2016-01-01          1       BOOKS    0.0            0

# %%
retail.info(memory_usage="deep")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1054944 entries, 0 to 1054943
# Data columns (total 6 columns):
#  #   Column       Non-Null Count    Dtype
# ---  ------       --------------    -----
#  0   id           1054944 non-null  int64
#  1   date         1054944 non-null  datetime64[ns]
#  2   store_nbr    1054944 non-null  int64
#  3   family       1054944 non-null  object
#  4   sales        1054944 non-null  float64
#  5   onpromotion  1054944 non-null  int64
# dtypes: datetime64[ns](1), float64(1), int64(3), object(1)
# memory usage: 108.4 MB

# %%
retail.loc[0,["date"]] = 'N/A'

retail.head()
# Out:
#         id        date  store_nbr      family  sales  onpromotion
# 0  1945944         N/A          1  AUTOMOTIVE    0.0            0
# 1  1945945  2016-01-01          1   BABY CARE    0.0            0
# 2  1945946  2016-01-01          1      BEAUTY    0.0            0
# 3  1945947  2016-01-01          1   BEVERAGES    0.0            0
# 4  1945948  2016-01-01          1       BOOKS    0.0            0

# %%
retail.astype({"date":"datetime64[ns]"})
# Out:
# ---------------------------------------------------------------------------
# DateParseError                            Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 retail.astype({"date":"datetime64[ns]"})
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/generic.py:6620, in NDFrame.astype(self, dtype, copy, errors)
#    6618 else:
#    6619     try:
# -> 6620         res_col = col.astype(dtype=cdt, copy=copy, errors=errors)
#    6621     except ValueError as ex:
#    6622         ex.args = (
#    6623             f"{ex}: Error while type casting for column '{col_name}'",
#    6624         )
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/generic.py:6643, in NDFrame.astype(self, dtype, copy, errors)
#    6637     results = [
#    6638         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6639     ]
#    6641 else:
#    6642     # else, only a single dtype is given
# ...

# %%
retail.assign(date=pd.to_datetime(retail["date"],
                                  errors="coerce",
                                  format="%Y-%m-%d"
                                  #infer_datetime_format=True
                                 )).dtypes
# Out:
# id                      int64
# date           datetime64[ns]
# store_nbr               int64
# family                 object
# sales                 float64
# onpromotion             int64
# dtype: object

# %%
retail.assign(date=pd.to_datetime(retail["date"],
                                  errors="coerce",
                                  format="%Y-%m-%d"
                                  #infer_datetime_format=True
                                 )).info(memory_usage="deep")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1054944 entries, 0 to 1054943
# Data columns (total 6 columns):
#  #   Column       Non-Null Count    Dtype
# ---  ------       --------------    -----
#  0   id           1054944 non-null  int64
#  1   date         1054944 non-null  datetime64[ns]
#  2   store_nbr    1054944 non-null  int64
#  3   family       1054944 non-null  object
#  4   sales        1054944 non-null  float64
#  5   onpromotion  1054944 non-null  int64
# dtypes: datetime64[ns](1), float64(1), int64(3), object(1)
# memory usage: 108.4 MB

# %%
now
# Out:
# datetime.datetime(2025, 3, 15, 22, 12, 56, 92439)

# %%
now.strftime("%B %d, %Y") # reverse to object ( string)
# Out:
# 'March 15, 2025'

# %%
retail = pd.read_csv("./retail/retail_2016_2017.csv", parse_dates=["date"])

retail.head()
# Out:
#         id       date  store_nbr      family  sales  onpromotion
# 0  1945944 2016-01-01          1  AUTOMOTIVE    0.0            0
# 1  1945945 2016-01-01          1   BABY CARE    0.0            0
# 2  1945946 2016-01-01          1      BEAUTY    0.0            0
# 3  1945947 2016-01-01          1   BEVERAGES    0.0            0
# 4  1945948 2016-01-01          1       BOOKS    0.0            0

# %%
retail.info(memory_usage="deep")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1054944 entries, 0 to 1054943
# Data columns (total 6 columns):
#  #   Column       Non-Null Count    Dtype
# ---  ------       --------------    -----
#  0   id           1054944 non-null  int64
#  1   date         1054944 non-null  datetime64[ns]
#  2   store_nbr    1054944 non-null  int64
#  3   family       1054944 non-null  object
#  4   sales        1054944 non-null  float64
#  5   onpromotion  1054944 non-null  int64
# dtypes: datetime64[ns](1), float64(1), int64(3), object(1)
# memory usage: 108.4 MB

# %%
retail["date"].dt.strftime("%Y").head()
# Out:
# 0    2016
# 1    2016
# 2    2016
# 3    2016
# 4    2016
# Name: date, dtype: object

# %%
retail["date"].dt.strftime("%y-%b-%d").head()
# Out:
# 0    16-Jan-01
# 1    16-Jan-01
# 2    16-Jan-01
# 3    16-Jan-01
# 4    16-Jan-01
# Name: date, dtype: object

# %%
retail["date"].dt.strftime("%y-%b,%d").head()
# Out:
# 0    16-Jan,01
# 1    16-Jan,01
# 2    16-Jan,01
# 3    16-Jan,01
# 4    16-Jan,01
# Name: date, dtype: object

# %% [markdown]
# ### extracting datetime components

# %%
retail.assign(
    year=retail["date"].dt.year,
    month=retail["date"].dt.month,
    dayofweek=retail["date"].dt.dayofweek,
    hour=retail["date"].dt.hour
)
# Out:
#               id       date  store_nbr                      family     sales  \
# 0        1945944 2016-01-01          1                  AUTOMOTIVE     0.000
# 1        1945945 2016-01-01          1                   BABY CARE     0.000
# 2        1945946 2016-01-01          1                      BEAUTY     0.000
# 3        1945947 2016-01-01          1                   BEVERAGES     0.000
# 4        1945948 2016-01-01          1                       BOOKS     0.000
# ...          ...        ...        ...                         ...       ...
# 1054939  3000883 2017-08-15          9                     POULTRY   438.133
# 1054940  3000884 2017-08-15          9              PREPARED FOODS   154.553
# 1054941  3000885 2017-08-15          9                     PRODUCE  2419.729
# 1054942  3000886 2017-08-15          9  SCHOOL AND OFFICE SUPPLIES   121.000
# 1054943  3000887 2017-08-15          9                     SEAFOOD    16.000
#
# ...

# %%
retail.assign(
    year=retail["date"].dt.year,
    month=retail["date"].dt.month,
    dayofweek=retail["date"].dt.dayofweek,
    hour=retail["date"].dt.hour
).dtypes
# Out:
# id                      int64
# date           datetime64[ns]
# store_nbr               int64
# family                 object
# sales                 float64
# onpromotion             int64
# year                    int32
# month                   int32
# dayofweek               int32
# hour                    int32
# dtype: object

# %% [markdown]
# ### Exercise 1 time to last date
# - create a column representing the time difference between the last date in the date and each date
# - create columns for year, month and weekday
# - format the date to Year-Month-Day

# %%
transactions = pd.read_csv("./retail/transactions.csv", parse_dates=["date"])

transactions.head()
# Out:
#         date  store_nbr  transactions
# 0 2013-01-01         25           770
# 1 2013-01-02          1          2111
# 2 2013-01-02          2          2358
# 3 2013-01-02          3          3487
# 4 2013-01-02          4          1922

# %%
transactions.dtypes
# Out:
# date            datetime64[ns]
# store_nbr                int64
# transactions             int64
# dtype: object

# %%
transactions["date"].max()
# Out:
# Timestamp('2017-08-15 00:00:00')

# %%
#create a column representing the time difference between the last date in the date and each date
transactions = transactions.assign(
    time_to_last_date = transactions["date"].max() - transactions["date"]
)

transactions.head()
# Out:
#         date  store_nbr  transactions time_to_last_date
# 0 2013-01-01         25           770         1687 days
# 1 2013-01-02          1          2111         1686 days
# 2 2013-01-02          2          2358         1686 days
# 3 2013-01-02          3          3487         1686 days
# 4 2013-01-02          4          1922         1686 days

# %%
#create columns for year, month and weekday

transactions = transactions.assign(
    year=retail["date"].dt.year,
    month=retail["date"].dt.month,
    day_of_week=retail["date"].dt.dayofweek
)

transactions.head()
# Out:
#         date  store_nbr  transactions  year  month  day_of_week
# 0 2013-01-01         25           770  2016      1            4
# 1 2013-01-02          1          2111  2016      1            4
# 2 2013-01-02          2          2358  2016      1            4
# 3 2013-01-02          3          3487  2016      1            4
# 4 2013-01-02          4          1922  2016      1            4

# %%
transactions = transactions.assign(date= transactions["date"].dt.strftime("%Y-%B-%d"))
transactions.head()
# Out:
#               date  store_nbr  transactions  year  month  day_of_week
# 0  2013-January-01         25           770  2016      1            4
# 1  2013-January-02          1          2111  2016      1            4
# 2  2013-January-02          2          2358  2016      1            4
# 3  2013-January-02          3          3487  2016      1            4
# 4  2013-January-02          4          1922  2016      1            4

# %%
# format date 
transactions["date"]= transactions["date"].dt.strftime("%Y-%B-%d")

transactions.head()
# Out:
#               date  store_nbr  transactions  year  month  day_of_week
# 0  2013-January-01         25           770  2016      1            4
# 1  2013-January-02          1          2111  2016      1            4
# 2  2013-January-02          2          2358  2016      1            4
# 3  2013-January-02          3          3487  2016      1            4
# 4  2013-January-02          4          1922  2016      1            4

# %% [markdown]
# ### time detals
# - dt.days
# - to_timedelta()
# - D,W,H,T,S

# %%
retail.head()
# Out:
#         id       date  store_nbr      family  sales  onpromotion
# 0  1945944 2016-01-01          1  AUTOMOTIVE    0.0            0
# 1  1945945 2016-01-01          1   BABY CARE    0.0            0
# 2  1945946 2016-01-01          1      BEAUTY    0.0            0
# 3  1945947 2016-01-01          1   BEVERAGES    0.0            0
# 4  1945948 2016-01-01          1       BOOKS    0.0            0

# %%
retail.info(memory_usage="deep")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1054944 entries, 0 to 1054943
# Data columns (total 6 columns):
#  #   Column       Non-Null Count    Dtype
# ---  ------       --------------    -----
#  0   id           1054944 non-null  int64
#  1   date         1054944 non-null  datetime64[ns]
#  2   store_nbr    1054944 non-null  int64
#  3   family       1054944 non-null  object
#  4   sales        1054944 non-null  float64
#  5   onpromotion  1054944 non-null  int64
# dtypes: datetime64[ns](1), float64(1), int64(3), object(1)
# memory usage: 108.4 MB

# %%
retail = retail.assign(
    birthday=pd.to_datetime("1950-01-01")
)

retail.head()
# Out:
#         id       date  store_nbr      family  sales  onpromotion   birthday
# 0  1945944 2016-01-01          1  AUTOMOTIVE    0.0            0 1950-01-01
# 1  1945945 2016-01-01          1   BABY CARE    0.0            0 1950-01-01
# 2  1945946 2016-01-01          1      BEAUTY    0.0            0 1950-01-01
# 3  1945947 2016-01-01          1   BEVERAGES    0.0            0 1950-01-01
# 4  1945948 2016-01-01          1       BOOKS    0.0            0 1950-01-01

# %%
retail = retail.assign(
    age=(retail["date"] - retail["birthday"]).dt.days/365.25
)

retail.head()
# Out:
#         id       date  store_nbr      family  sales  onpromotion   birthday  \
# 0  1945944 2016-01-01          1  AUTOMOTIVE    0.0            0 1950-01-01
# 1  1945945 2016-01-01          1   BABY CARE    0.0            0 1950-01-01
# 2  1945946 2016-01-01          1      BEAUTY    0.0            0 1950-01-01
# 3  1945947 2016-01-01          1   BEVERAGES    0.0            0 1950-01-01
# 4  1945948 2016-01-01          1       BOOKS    0.0            0 1950-01-01
#
#          age
# 0  65.998631
# 1  65.998631
# 2  65.998631
# 3  65.998631
# 4  65.998631

# %%
retail = retail.assign(
    retirement_date= retail["date"] + (pd.to_timedelta(365.25, unit='D')*20))

retail.head()
# Out:
#         id       date  store_nbr      family  sales  onpromotion   birthday  \
# 0  1945944 2016-01-01          1  AUTOMOTIVE    0.0            0 1950-01-01
# 1  1945945 2016-01-01          1   BABY CARE    0.0            0 1950-01-01
# 2  1945946 2016-01-01          1      BEAUTY    0.0            0 1950-01-01
# 3  1945947 2016-01-01          1   BEVERAGES    0.0            0 1950-01-01
# 4  1945948 2016-01-01          1       BOOKS    0.0            0 1950-01-01
#
#          age retirement_date
# 0  65.998631      2036-01-01
# 1  65.998631      2036-01-01
# 2  65.998631      2036-01-01
# 3  65.998631      2036-01-01
# 4  65.998631      2036-01-01

# %% [markdown]
# ### Exercise time to last date
# - 3 weeks after max date
# - week_to_last_date by dividing number of days in "time_to_last_date' by 7

# %%
transactions.head()
# Out:
#               date  store_nbr  transactions  year  month  day_of_week
# 0  2013-January-01         25           770  2016      1            4
# 1  2013-January-02          1          2111  2016      1            4
# 2  2013-January-02          2          2358  2016      1            4
# 3  2013-January-02          3          3487  2016      1            4
# 4  2013-January-02          4          1922  2016      1            4

# %%
transactions.dtypes
# Out:
# date            object
# store_nbr        int64
# transactions     int64
# year             int32
# month            int32
# day_of_week      int32
# dtype: object

# %%
transactions = transactions.astype({"date" : "datetime64[ns]"})

# %%
transactions.dtypes
# Out:
# date            datetime64[ns]
# store_nbr                int64
# transactions             int64
# year                     int32
# month                    int32
# day_of_week              int32
# dtype: object

# %%
transactions = transactions.assign(
    time_to_last_date = transactions["date"].max() - transactions["date"]
)

transactions.head()
# Out:
#         date  store_nbr  transactions  year  month  day_of_week  \
# 0 2013-01-01         25           770  2016      1            4
# 1 2013-01-02          1          2111  2016      1            4
# 2 2013-01-02          2          2358  2016      1            4
# 3 2013-01-02          3          3487  2016      1            4
# 4 2013-01-02          4          1922  2016      1            4
#
#   time_to_last_date
# 0         1687 days
# 1         1686 days
# 2         1686 days
# 3         1686 days
# 4         1686 days

# %%
#3 weeks after max date
# retail = retail.assign(
#     retirement_date= retail["date"] + (pd.to_timedelta(365.25, unit='D')*20))
transactions["time_to_last_date"] = transactions["time_to_last_date"] + pd.to_timedelta(1, unit='W')*3

transactions.head()
# Out:
#         date  store_nbr  transactions  year  month  day_of_week  \
# 0 2013-01-01         25           770  2016      1            4
# 1 2013-01-02          1          2111  2016      1            4
# 2 2013-01-02          2          2358  2016      1            4
# 3 2013-01-02          3          3487  2016      1            4
# 4 2013-01-02          4          1922  2016      1            4
#
#   time_to_last_date
# 0         1708 days
# 1         1707 days
# 2         1707 days
# 3         1707 days
# 4         1707 days

# %%
#week_to_last_date by dividing number of days in "time_to_last_date' by 7

transactions.assign(
        week_to_last_date =  transactions["time_to_last_date"].dt.days/7
)
# Out:
#             date  store_nbr  transactions  year  month  day_of_week  \
# 0     2013-01-01         25           770  2016      1            4
# 1     2013-01-02          1          2111  2016      1            4
# 2     2013-01-02          2          2358  2016      1            4
# 3     2013-01-02          3          3487  2016      1            4
# 4     2013-01-02          4          1922  2016      1            4
# ...          ...        ...           ...   ...    ...          ...
# 83483 2017-08-15         50          2804  2016      2            1
# 83484 2017-08-15         51          1573  2016      2            1
# 83485 2017-08-15         52          2255  2016      2            1
# 83486 2017-08-15         53           932  2016      2            1
# 83487 2017-08-15         54           802  2016      2            1
#
#       time_to_last_date  week_to_last_date
# 0             1708 days         244.000000
# 1             1707 days         243.857143
# ...

# %%
transactions.assign(
   time_to_last_date = transactions["time_to_last_date"] + pd.to_timedelta(3, unit='W'),
    weeks_to_last_date = (lambda x:x["time_to_last_date"].dt.days/7))

#transactions.head()
# Out:
#             date  store_nbr  transactions  year  month  day_of_week  \
# 0     2013-01-01         25           770  2016      1            4
# 1     2013-01-02          1          2111  2016      1            4
# 2     2013-01-02          2          2358  2016      1            4
# 3     2013-01-02          3          3487  2016      1            4
# 4     2013-01-02          4          1922  2016      1            4
# ...          ...        ...           ...   ...    ...          ...
# 83483 2017-08-15         50          2804  2016      2            1
# 83484 2017-08-15         51          1573  2016      2            1
# 83485 2017-08-15         52          2255  2016      2            1
# 83486 2017-08-15         53           932  2016      2            1
# 83487 2017-08-15         54           802  2016      2            1
#
#       time_to_last_date  weeks_to_last_date
# 0             1729 days          247.000000
# 1             1728 days          246.857143
# ...

# %% [markdown]
# ### time series indices
# - sorted is required for correct analysis
# - slice and partial year, month works , bet dates also works

# %%
retail = pd.read_csv("./retail/retail_2016_2017.csv", parse_dates=["date"])

retail.head()
# Out:
#         id       date  store_nbr      family  sales  onpromotion
# 0  1945944 2016-01-01          1  AUTOMOTIVE    0.0            0
# 1  1945945 2016-01-01          1   BABY CARE    0.0            0
# 2  1945946 2016-01-01          1      BEAUTY    0.0            0
# 3  1945947 2016-01-01          1   BEVERAGES    0.0            0
# 4  1945948 2016-01-01          1       BOOKS    0.0            0

# %%
retail.dtypes
# Out:
# id                      int64
# date           datetime64[ns]
# store_nbr               int64
# family                 object
# sales                 float64
# onpromotion             int64
# dtype: object

# %%
retail.index = retail["date"]

# %%
retail.head()
# Out:
#                  id       date  store_nbr      family  sales  onpromotion
# date
# 2016-01-01  1945944 2016-01-01          1  AUTOMOTIVE    0.0            0
# 2016-01-01  1945945 2016-01-01          1   BABY CARE    0.0            0
# 2016-01-01  1945946 2016-01-01          1      BEAUTY    0.0            0
# 2016-01-01  1945947 2016-01-01          1   BEVERAGES    0.0            0
# 2016-01-01  1945948 2016-01-01          1       BOOKS    0.0            0

# %%
retail.loc["2017"]
# Out:
#                  id       date  store_nbr                      family  \
# date
# 2017-01-01  2596374 2017-01-01          1                  AUTOMOTIVE
# 2017-01-01  2596375 2017-01-01          1                   BABY CARE
# 2017-01-01  2596376 2017-01-01          1                      BEAUTY
# 2017-01-01  2596377 2017-01-01          1                   BEVERAGES
# 2017-01-01  2596378 2017-01-01          1                       BOOKS
# ...             ...        ...        ...                         ...
# 2017-08-15  3000883 2017-08-15          9                     POULTRY
# 2017-08-15  3000884 2017-08-15          9              PREPARED FOODS
# 2017-08-15  3000885 2017-08-15          9                     PRODUCE
# 2017-08-15  3000886 2017-08-15          9  SCHOOL AND OFFICE SUPPLIES
# 2017-08-15  3000887 2017-08-15          9                     SEAFOOD
#
#                sales  onpromotion
# date
# 2017-01-01     0.000            0
# 2017-01-01     0.000            0
# ...

# %%
retail.loc["2017-08"]
# Out:
#                  id       date  store_nbr                      family  \
# date
# 2017-08-01  2974158 2017-08-01          1                  AUTOMOTIVE
# 2017-08-01  2974159 2017-08-01          1                   BABY CARE
# 2017-08-01  2974160 2017-08-01          1                      BEAUTY
# 2017-08-01  2974161 2017-08-01          1                   BEVERAGES
# 2017-08-01  2974162 2017-08-01          1                       BOOKS
# ...             ...        ...        ...                         ...
# 2017-08-15  3000883 2017-08-15          9                     POULTRY
# 2017-08-15  3000884 2017-08-15          9              PREPARED FOODS
# 2017-08-15  3000885 2017-08-15          9                     PRODUCE
# 2017-08-15  3000886 2017-08-15          9  SCHOOL AND OFFICE SUPPLIES
# 2017-08-15  3000887 2017-08-15          9                     SEAFOOD
#
#                sales  onpromotion
# date
# 2017-08-01     5.000            0
# 2017-08-01     0.000            0
# ...

# %%
retail.loc["2017-08-01"]
# Out:
#                  id       date  store_nbr                      family  \
# date
# 2017-08-01  2974158 2017-08-01          1                  AUTOMOTIVE
# 2017-08-01  2974159 2017-08-01          1                   BABY CARE
# 2017-08-01  2974160 2017-08-01          1                      BEAUTY
# 2017-08-01  2974161 2017-08-01          1                   BEVERAGES
# 2017-08-01  2974162 2017-08-01          1                       BOOKS
# ...             ...        ...        ...                         ...
# 2017-08-01  2975935 2017-08-01          9                     POULTRY
# 2017-08-01  2975936 2017-08-01          9              PREPARED FOODS
# 2017-08-01  2975937 2017-08-01          9                     PRODUCE
# 2017-08-01  2975938 2017-08-01          9  SCHOOL AND OFFICE SUPPLIES
# 2017-08-01  2975939 2017-08-01          9                     SEAFOOD
#
#                   sales  onpromotion
# date
# 2017-08-01     5.000000            0
# 2017-08-01     0.000000            0
# ...

# %%
retail.loc["2016-03":"2017-08-01"]
# Out:
#                  id       date  store_nbr                      family  \
# date
# 2016-03-01  2052864 2016-03-01          1                  AUTOMOTIVE
# 2016-03-01  2052865 2016-03-01          1                   BABY CARE
# 2016-03-01  2052866 2016-03-01          1                      BEAUTY
# 2016-03-01  2052867 2016-03-01          1                   BEVERAGES
# 2016-03-01  2052868 2016-03-01          1                       BOOKS
# ...             ...        ...        ...                         ...
# 2017-08-01  2975935 2017-08-01          9                     POULTRY
# 2017-08-01  2975936 2017-08-01          9              PREPARED FOODS
# 2017-08-01  2975937 2017-08-01          9                     PRODUCE
# 2017-08-01  2975938 2017-08-01          9  SCHOOL AND OFFICE SUPPLIES
# 2017-08-01  2975939 2017-08-01          9                     SEAFOOD
#
#                   sales  onpromotion
# date
# 2016-03-01     5.000000            0
# 2016-03-01     0.000000            0
# ...

# %% [markdown]
# ### fixing missing data
# - ffill()
# - bfill()
# - interpolate() - linear approximation

# %%
retail = pd.read_csv("./retail/retail_2016_2017.csv", parse_dates=["date"])

retail.head()
# Out:
#         id       date  store_nbr      family  sales  onpromotion
# 0  1945944 2016-01-01          1  AUTOMOTIVE    0.0            0
# 1  1945945 2016-01-01          1   BABY CARE    0.0            0
# 2  1945946 2016-01-01          1      BEAUTY    0.0            0
# 3  1945947 2016-01-01          1   BEVERAGES    0.0            0
# 4  1945948 2016-01-01          1       BOOKS    0.0            0

# %%
retail_agg = retail.groupby(["date"]).agg({"sales":"sum"}).round().iloc[:10]

retail_agg
# Out:
#                 sales
# date
# 2016-01-01    16433.0
# 2016-01-02  1066677.0
# 2016-01-03  1226736.0
# 2016-01-04   955957.0
# 2016-01-05   835320.0
# 2016-01-06   821686.0
# 2016-01-07   653504.0
# 2016-01-08   713608.0
# 2016-01-09   989209.0
# 2016-01-10  1094694.0

# %%
retail_agg.plot();

# %%
import numpy as np
retail_agg.iloc[1] = np.nan
retail_agg.iloc[4:6]=np.nan

retail_agg
# Out:
#                 sales
# date
# 2016-01-01    16433.0
# 2016-01-02        NaN
# 2016-01-03  1226736.0
# 2016-01-04   955957.0
# 2016-01-05        NaN
# 2016-01-06        NaN
# 2016-01-07   653504.0
# 2016-01-08   713608.0
# 2016-01-09   989209.0
# 2016-01-10  1094694.0

# %%
retail_agg.plot()
# Out:
# <Axes: xlabel='date'>

# %%
retail_agg.fillna(retail_agg["sales"].mean())
# Out:
#                 sales
# date
# 2016-01-01    16433.0
# 2016-01-02   807163.0
# 2016-01-03  1226736.0
# 2016-01-04   955957.0
# 2016-01-05   807163.0
# 2016-01-06   807163.0
# 2016-01-07   653504.0
# 2016-01-08   713608.0
# 2016-01-09   989209.0
# 2016-01-10  1094694.0

# %%
retail_agg.fillna(retail_agg["sales"].mean()).plot();

# %%
retail_agg.ffill()
# Out:
#                 sales
# date
# 2016-01-01    16433.0
# 2016-01-02    16433.0
# 2016-01-03  1226736.0
# 2016-01-04   955957.0
# 2016-01-05   955957.0
# 2016-01-06   955957.0
# 2016-01-07   653504.0
# 2016-01-08   713608.0
# 2016-01-09   989209.0
# 2016-01-10  1094694.0

# %%
retail_agg.ffill().plot();

# %%
retail_agg.bfill()
# Out:
#                 sales
# date
# 2016-01-01    16433.0
# 2016-01-02  1226736.0
# 2016-01-03  1226736.0
# 2016-01-04   955957.0
# 2016-01-05   653504.0
# 2016-01-06   653504.0
# 2016-01-07   653504.0
# 2016-01-08   713608.0
# 2016-01-09   989209.0
# 2016-01-10  1094694.0

# %%
retail_agg.bfill().plot()
# Out:
# <Axes: xlabel='date'>

# %%
retail_agg.interpolate()
# Out:
#                    sales
# date
# 2016-01-01  1.643300e+04
# 2016-01-02  6.215845e+05
# 2016-01-03  1.226736e+06
# 2016-01-04  9.559570e+05
# 2016-01-05  8.551393e+05
# 2016-01-06  7.543217e+05
# 2016-01-07  6.535040e+05
# 2016-01-08  7.136080e+05
# 2016-01-09  9.892090e+05
# 2016-01-10  1.094694e+06

# %%
retail_agg.interpolate().plot();

# %% [markdown]
# ### missing oil prices
# - mean value of oil prices using forward fill , backfill and interpolation
#
# - plot the series with forward fill for :
#
# - the year of 2014
#
# - month of Dec 2014
#
# - days from dec 1st to Dec 15th, 2014

# %%
oil = pd.read_csv("./retail/oil.csv",
                  index_col="date",
                  parse_dates=True)

# %%
oil.index.dtype
# Out:
# dtype('<M8[ns]')

# %%
oil.mean()
# Out:
# dcoilwtico    67.714366
# dtype: float64

# %%
oil.plot()
# Out:
# <Axes: xlabel='date'>

# %%
oil.ffill().mean()
# Out:
# dcoilwtico    67.671249
# dtype: float64

# %%
oil.bfill().mean()
# Out:
# dcoilwtico    67.673325
# dtype: float64

# %%
oil.interpolate().mean()
# Out:
# dcoilwtico    67.661824
# dtype: float64

# %%
oil.query("date.dt.year == 2014").ffill().plot()
# Out:
# <Axes: xlabel='date'>

# %%
oil.loc["2014"].ffill().plot()
# Out:
# <Axes: xlabel='date'>

# %%
oil.loc["2014-12"].ffill().plot();

# %%
oil.loc["2014-12-1":"2014-12-15"].ffill().plot();

# %% [markdown]
# ### shift the series
# - shift()
# - shift(-1)
# - (dates/dates.shift(1)).sub(1).mul(100).round(2)
# - % Growth = Current Period/Previous Period -1

# %%
retail = pd.read_csv("./retail/retail_2016_2017.csv", parse_dates=["date"])

retail.head()
# Out:
#         id       date  store_nbr      family  sales  onpromotion
# 0  1945944 2016-01-01          1  AUTOMOTIVE    0.0            0
# 1  1945945 2016-01-01          1   BABY CARE    0.0            0
# 2  1945946 2016-01-01          1      BEAUTY    0.0            0
# 3  1945947 2016-01-01          1   BEVERAGES    0.0            0
# 4  1945948 2016-01-01          1       BOOKS    0.0            0

# %%
retail_agg = retail.groupby(["date"]).agg({"sales":"sum"}).round().iloc[1:10]

retail_agg
# Out:
#                 sales
# date
# 2016-01-02  1066677.0
# 2016-01-03  1226736.0
# 2016-01-04   955957.0
# 2016-01-05   835320.0
# 2016-01-06   821686.0
# 2016-01-07   653504.0
# 2016-01-08   713608.0
# 2016-01-09   989209.0
# 2016-01-10  1094694.0

# %%
retail_agg.assign(yesterday_sales = retail_agg["sales"] / retail_agg["sales"].shift())
# Out:
#                 sales  yesterday_sales
# date
# 2016-01-02  1066677.0              NaN
# 2016-01-03  1226736.0         1.150054
# 2016-01-04   955957.0         0.779269
# 2016-01-05   835320.0         0.873805
# 2016-01-06   821686.0         0.983678
# 2016-01-07   653504.0         0.795321
# 2016-01-08   713608.0         1.091972
# 2016-01-09   989209.0         1.386208
# 2016-01-10  1094694.0         1.106636

# %% [markdown]
# ### diff() method row prior

# %%
retail_agg
# Out:
#                 sales
# date
# 2016-01-02  1066677.0
# 2016-01-03  1226736.0
# 2016-01-04   955957.0
# 2016-01-05   835320.0
# 2016-01-06   821686.0
# 2016-01-07   653504.0
# 2016-01-08   713608.0
# 2016-01-09   989209.0
# 2016-01-10  1094694.0

# %%
retail_agg.assign(daily_change = retail_agg["sales"].diff())
# Out:
#                 sales  daily_change
# date
# 2016-01-02  1066677.0           NaN
# 2016-01-03  1226736.0      160059.0
# 2016-01-04   955957.0     -270779.0
# 2016-01-05   835320.0     -120637.0
# 2016-01-06   821686.0      -13634.0
# 2016-01-07   653504.0     -168182.0
# 2016-01-08   713608.0       60104.0
# 2016-01-09   989209.0      275601.0
# 2016-01-10  1094694.0      105485.0

# %%
retail_agg.assign(daily_change = retail_agg["sales"].diff() / retail_agg["sales"].shift())
# Out:
#                 sales  daily_change
# date
# 2016-01-02  1066677.0           NaN
# 2016-01-03  1226736.0      0.150054
# 2016-01-04   955957.0     -0.220731
# 2016-01-05   835320.0     -0.126195
# 2016-01-06   821686.0     -0.016322
# 2016-01-07   653504.0     -0.204679
# 2016-01-08   713608.0      0.091972
# 2016-01-09   989209.0      0.386208
# 2016-01-10  1094694.0      0.106636

# %% [markdown]
# ### Exercise monthly lookback chart
# YoY trends at store 47
# -plot the sum of monthly tx in year 2015 vs the sum of monthly tx in the year prior for store 47
# - group df by year and month

# %%
transactions = pd.read_csv("./retail/transactions.csv", parse_dates=["date"])

#transactions = transactions.query("store_nbr == 47")

transactions.head()
# Out:
#         date  store_nbr  transactions
# 0 2013-01-01         25           770
# 1 2013-01-02          1          2111
# 2 2013-01-02          2          2358
# 3 2013-01-02          3          3487
# 4 2013-01-02          4          1922

# %%
transactions.dtypes
# Out:
# date            datetime64[ns]
# store_nbr                int64
# transactions             int64
# dtype: object

# %%
# transactions.index = transactions["date"]

# transactions.head()
retail_agg = retail.groupby(["date"]).agg({"sales":"sum"}).round().iloc[1:10]

# %%
transactions["year"] = transactions["date"].dt.year
transactions["month"] = transactions["date"].dt.month
transactions_agg = transactions.groupby(["year","month"]).agg({"transactions":"sum"}).round() #.iloc[1:10]
transactions_agg.head()
# Out:
#             transactions
# year month
# 2013 1            109668
#      2            103706
#      3            116873
#      4            108571
#      5            113532

# %%
transactions_agg.assign(monthly_change = transactions_agg["transactions"].diff() / retail_agg["transactions"].shift())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'transactions'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[182], line 1
# ...

# %%
transactions.head()
# Out:
#         date  store_nbr  transactions
# 0 2013-01-01         25           770
# 1 2013-01-02          1          2111
# 2 2013-01-02          2          2358
# 3 2013-01-02          3          3487
# 4 2013-01-02          4          1922

# %%
transactions_47 = transactions.loc[transactions["store_nbr"]==47, ["date","transactions"]]
transactions_47.dtypes


    
# transactions_47.head()
# Out:
# date            datetime64[ns]
# transactions             int64
# dtype: object

# %%
transactions_47 = (transactions_47
                  .groupby([transactions["date"].dt.year, transactions["date"].dt.month])
                  .sum())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[203], line 1
# ----> 1 transactions_47 = (transactions_47
#       2                   .groupby([transactions["date"].dt.year, transactions["date"].dt.month])
#       3                   .sum())
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/groupby/groupby.py:3146, in GroupBy.sum(self, numeric_only, min_count, engine, engine_kwargs)
#    3141 else:
#    3142     # If we are grouping on categoricals we want unobserved categories to
#    3143     # return zero, rather than the default of NaN which the reindexing in
#    3144     # _agg_general() returns. GH #31422
#    3145     with com.temp_setattr(self, "observed", True):
# -> 3146         result = self._agg_general(
#    3147             numeric_only=numeric_only,
#    3148             min_count=min_count,
#    3149             alias="sum",
# ...

# %%
transactions_47["year"] = transactions_47["date"].dt.year
transactions_47["month"] = transactions_47["date"].dt.month

transactions_47_grouped = (
    transactions_47.groupby(["year", "month"])["transactions"]
    .sum()
    .reset_index()
)

transactions_47_grouped.head()
# Out:
#    year  month  transactions
# 0  2013      1        109668
# 1  2013      2        103706
# 2  2013      3        116873
# 3  2013      4        108571
# 4  2013      5        113532

# %%
transactions_47_grouped2 = (
    transactions_47
    .groupby(pd.Grouper(key="date", freq="M"))["transactions"]
    .sum()
    .reset_index()
)

transactions_47_grouped2.head()
# Out:
# /var/folders/vz/kll226bs5z166d_j4rg4kj2m0000gn/T/ipykernel_98568/3228393364.py:3: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   .groupby(pd.Grouper(key="date", freq="M"))["transactions"]
#         date  transactions
# 0 2013-01-31        109668
# 1 2013-02-28        103706
# 2 2013-03-31        116873
# 3 2013-04-30        108571
# 4 2013-05-31        113532

# %%
transactions_47_grouped["year_prior"] = transactions_47_grouped["transactions"].shift(12)

transactions_47_grouped.head(24)
# Out:
#     year  month  transactions  year_prior
# 0   2013      1        109668         NaN
# 1   2013      2        103706         NaN
# 2   2013      3        116873         NaN
# 3   2013      4        108571         NaN
# 4   2013      5        113532         NaN
# 5   2013      6        110637         NaN
# 6   2013      7        107506         NaN
# 7   2013      8        112001         NaN
# 8   2013      9        114468         NaN
# 9   2013     10        114585         NaN
# 10  2013     11        114436         NaN
# 11  2013     12        150204         NaN
# 12  2014      1        114190    109668.0
# 13  2014      2        107175    103706.0
# 14  2014      3        121771    116873.0
# 15  2014      4        122976    108571.0
# 16  2014      5        126298    113532.0
# 17  2014      6        118398    110637.0
# 18  2014      7        118522    107506.0
# 19  2014      8        121949    112001.0
# 20  2014      9        115552    114468.0
# ...

# %%
transactions_47_grouped.loc[transactions_47_grouped["year"] == 2015].plot()
# Out:
# <Axes: >

# %%
import matplotlib.pyplot as plt

ax = transactions_47_grouped.loc[transactions_47_grouped["year"] == 2015].plot()

# Set the lower limit of the y-axis to 12,000
ax.set_ylim(12000, None)

plt.show()

# %%
transactions_47_final = transactions_47_grouped.loc[transactions_47_grouped["year"] == 2015, ["transactions","year_prior"]]

#transactions_47 = transactions.loc[transactions["store_nbr"]==47, ["date","transactions"]]

transactions_47_final.head()
# Out:
#     transactions  year_prior
# 24        118445    114190.0
# 25        108186    107175.0
# 26        119883    121771.0
# 27        118449    122976.0
# 28        120810    126298.0

# %%
transactions_47_final.plot();

# %% [markdown]
# ### agg using groupby() resample

# %%
retail = pd.read_csv("./retail/retail_2016_2017.csv", parse_dates=["date"])

retail.head()
# Out:
#         id       date  store_nbr      family  sales  onpromotion
# 0  1945944 2016-01-01          1  AUTOMOTIVE    0.0            0
# 1  1945945 2016-01-01          1   BABY CARE    0.0            0
# 2  1945946 2016-01-01          1      BEAUTY    0.0            0
# 3  1945947 2016-01-01          1   BEVERAGES    0.0            0
# 4  1945948 2016-01-01          1       BOOKS    0.0            0

# %%
#retail.groupby([retail["date"].dt.year,retail["date"].dt.month]).agg("sum").round(2)

retail.groupby([retail["date"].dt.year, retail["date"].dt.month])["sales"].agg("sum").round(2)
# Out:
# date  date
# 2016  1       23977804.89
#       2       21947408.80
#       3       23131780.88
#       4       25963025.10
#       5       24779432.26
#       6       22209218.58
#       7       23462672.43
#       8       22452414.32
#       9       22417448.10
#       10      24030389.82
#       11      24642640.20
#       12      29640287.58
# 2017  1       26328159.94
#       2       23250112.37
#       3       26704017.69
#       4       25895308.49
#       5       26911847.25
#       6       25682822.12
#       7       27011477.57
#       8       12433322.94
# Name: sales, dtype: float64

# %%
retail.set_index("date").resample("ME").sum().round(2)
# Out:
#                       id  store_nbr  \
# date
# 2016-01-31  109023650109    1519155
# 2016-02-29  104752572111    1421145
# 2016-03-31  114930124749    1519155
# 2016-04-30  114128305830    1470150
# 2016-05-31  120935040633    1519155
# 2016-06-30  119939514750    1470150
# 2016-07-31  126939956517    1519155
# 2016-08-31  129991635081    1519155
# 2016-09-30  128703960990    1470150
# 2016-10-31  135996550965    1519155
# 2016-11-30  134515169910    1470150
# 2016-12-31  137373141510    1470150
# 2017-01-31  144954704169    1519155
# 2017-02-28  133549812396    1372140
# 2017-03-31  150762737565    1519155
# 2017-04-30  148805027910    1470150
# 2017-05-31  156767653449    1519155
# 2017-06-30  154616236830    1470150
# 2017-07-31  162772569333    1519155
# 2017-08-31   79856476425     735075
#
#                                                        family        sales  \
# date
# 2016-01-31  AUTOMOTIVEBABY CAREBEAUTYBEVERAGESBOOKSBREAD/B...  23977804.89
# ...

# %% [markdown]
# ### exercise charts of avg oil price by month and year

# %%
oil = pd.read_csv("./retail/oil.csv",
                  index_col="date",
                  parse_dates=True)

# %%
oil.head()
# Out:
#             dcoilwtico
# date
# 2013-01-01         NaN
# 2013-01-02       93.14
# 2013-01-03       92.97
# 2013-01-04       93.12
# 2013-01-07       93.20

# %%
oil.resample('ME').mean().plot()
# Out:
# <Axes: xlabel='date'>

# %%
oil.resample('YE').mean().plot()
# Out:
# <Axes: xlabel='date'>

# %%
for period in ["D","W","ME","YE"]:
    oil.resample(period).mean().plot()

# %% [markdown]
# ### rolling aggregations
# rolling()

# %%
retail.head()
# Out:
#         id       date  store_nbr      family  sales  onpromotion
# 0  1945944 2016-01-01          1  AUTOMOTIVE    0.0            0
# 1  1945945 2016-01-01          1   BABY CARE    0.0            0
# 2  1945946 2016-01-01          1      BEAUTY    0.0            0
# 3  1945947 2016-01-01          1   BEVERAGES    0.0            0
# 4  1945948 2016-01-01          1       BOOKS    0.0            0

# %%
retail_daily = retail.set_index("date").loc[:,"sales"].resample("D").sum().round(2)

retail_daily
# Out:
# date
# 2016-01-01      16433.39
# 2016-01-02    1066677.42
# 2016-01-03    1226735.72
# 2016-01-04     955956.88
# 2016-01-05     835320.44
#                  ...
# 2017-08-11     826373.72
# 2017-08-12     792630.54
# 2017-08-13     865639.68
# 2017-08-14     760922.41
# 2017-08-15     762661.94
# Freq: D, Name: sales, Length: 593, dtype: float64

# %%
retail_daily.rolling(2).mean()
# Out:
# date
# 2016-01-01            NaN
# 2016-01-02     541555.405
# 2016-01-03    1146706.570
# 2016-01-04    1091346.300
# 2016-01-05     895638.660
#                  ...
# 2017-08-11     738880.315
# 2017-08-12     809502.130
# 2017-08-13     829135.110
# 2017-08-14     813281.045
# 2017-08-15     761792.175
# Freq: D, Name: sales, Length: 593, dtype: float64

# %%
retail_daily.plot()
# Out:
# <Axes: xlabel='date'>

# %%
retail_daily.rolling(2).mean().plot()
# Out:
# <Axes: xlabel='date'>

# %%
retail_daily.rolling(30).mean().plot();

# %%
retail_daily.rolling(90).mean().plot();

# %%
retail_daily.rolling(7).mean().plot();

# %% [markdown]
# ### Exercise rolling tx for 47

# %%
transactions_47.head()
# Out:
#           date  transactions  year  month
# 41  2013-01-02          4161  2013      1
# 87  2013-01-03          3660  2013      1
# 133 2013-01-04          3915  2013      1
# 179 2013-01-05          4764  2013      1
# 225 2013-01-06          4935  2013      1

# %%
transactions_47 = transactions_47[["date","transactions"]]

transactions_47.head()
# Out:
#           date  transactions
# 41  2013-01-02          4161
# 87  2013-01-03          3660
# 133 2013-01-04          3915
# 179 2013-01-05          4764
# 225 2013-01-06          4935

# %%
transactions_47.index = transactions_47["date"]

# %%
transactions_47.head()
# Out:
#                  date  transactions
# date
# 2013-01-02 2013-01-02          4161
# 2013-01-03 2013-01-03          3660
# 2013-01-04 2013-01-04          3915
# 2013-01-05 2013-01-05          4764
# 2013-01-06 2013-01-06          4935

# %%
transactions_47 = transactions_47.set_index("date")[["transactions"]]

# %%
transactions_47.head()
# Out:
#             transactions
# date
# 2013-01-02          4161
# 2013-01-03          3660
# 2013-01-04          3915
# 2013-01-05          4764
# 2013-01-06          4935

# %%
transactions = pd.read_csv("./retail/transactions.csv", parse_dates=["date"])

#transactions = transactions.query("store_nbr == 47")

transactions.head()
# Out:
#         date  store_nbr  transactions
# 0 2013-01-01         25           770
# 1 2013-01-02          1          2111
# 2 2013-01-02          2          2358
# 3 2013-01-02          3          3487
# 4 2013-01-02          4          1922

# %%
transactions_47 =(transactions
                  .loc[transactions["store_nbr"]==47,["date","transactions"]]
                  .set_index("date"))

transactions_47.head()
# Out:
#             transactions
# date
# 2013-01-02          4161
# 2013-01-03          3660
# 2013-01-04          3915
# 2013-01-05          4764
# 2013-01-06          4935

# %%
transactions_47.rolling(90).mean().plot()
# Out:
# <Axes: xlabel='date'>

# %%
(transactions_47
 .assign(transaction_rolling_avg_90 =transactions_47.rolling(90).mean())
         .drop(["transactions"], axis=1)
         .plot());
